# %%
pip install pytrends

# %%
from pytrends.request import TrendReq
pytrend = TrendReq()

topics_data = pytrend.suggestions(keyword='Unemployment benefits')
topics_data
# Out:
# [{'mid': '/m/0218w7', 'title': 'Unemployment benefits', 'type': 'Topic'},
#  {'mid': '/g/11j5_zdslp',
#   'title': 'Unemployment benefits in New Jersey',
#   'type': 'Topic'},
#  {'mid': '/g/11jg4j171x',
#   'title': 'Unemployment benefits in Ohio',
#   'type': 'Topic'},
#  {'mid': '/g/11jg4s451x',
#   'title': 'Unemployment benefits in New York',
#   'type': 'Topic'},
#  {'mid': '/g/11jg4ldpyf',
#   'title': 'Unemployment benefits in Texas',
#   'type': 'Topic'}]

# %%
from pytrends.request import TrendReq

pytrends = TrendReq(hl='en-Es', tz=360)
suggs = pytrends.suggestions("Labour Market")
suggs
# Out:
# [{'mid': '/m/011x5vx5',
#   'title': 'Labour Market Regulatory Authority',
#   'type': 'Governing body'},
#  {'mid': '/g/11j775y04_',
#   'title': 'Labour Market Impact Assessment',
#   'type': 'Topic'},
#  {'mid': '/g/121v2c3t', 'title': 'labour market subsidy', 'type': 'Topic'},
#  {'mid': '/g/12bpb3230',
#   'title': 'International Human Resource Management',
#   'type': 'Book'},
#  {'mid': '/g/1n36gmq6p',
#   'title': 'labour market contribution (Denmark)',
#   'type': 'Topic'}]

# %% [markdown]
# country_list = ['AT', 'BE', 'CH', 'CY', 'CZ', 'DE', 'DK', 'EE', 'EL', 'ES',
#        'FI', 'FR', 'HU', 'IE', 'IS', 'IT', 'LU', 'ME',
#        'MT', 'NL', 'NO', 'PL', 'PT', 'SE', 'SI', 'UK',
#         'LT', 'LV']

# %%
pytrend = TrendReq()
topics_data = pytrend.suggestions(keyword='Education')
topics_data # SIGUEN SALIENDOME OTROS
# Out:
# [{'mid': '/g/121p6d90', 'title': 'Education', 'type': 'Professional field'},
#  {'mid': '/m/01qk7d',
#   'title': 'Educational software',
#   'type': 'Software type'},
#  {'mid': '/g/11fmh5048z',
#   'title': 'When Stars Are Scattered',
#   'type': 'Novel by Omar Mohamed and Victoria Jamieson'},
#  {'mid': '/g/11dzss3vmv',
#   'title': 'Oh Joy, Sex Toy',
#   'type': 'Book by Erika Moen'},
#  {'mid': '/g/11p0zv9_04',
#   'title': 'I Must Betray You',
#   'type': 'Book by Ruta Sepetys'}]

# %%
pip install FastAPI

# %%
# El it s GR in pytrends
import time
from pytrends.request import TrendReq
from fastapi import FastAPI
import pandas as pd

app = FastAPI()

def obtener_datos_google_trends_semanal(palabra_clave):
    try:
        pytrends = TrendReq(hl='es', tz=360)
        pytrends.build_payload(kw_list=[palabra_clave], timeframe='2014-01-01 2024-03-31', geo='GR')
        data = pytrends.interest_over_time()
        data_semanal = data.resample('W').mean()
        return data_semanal
    except Exception as e:
        print(f"Error al obtener datos de Google Trends: {e}")
        time.sleep(60)
        return obtener_datos_google_trends_semanal(palabra_clave)

@app.get("/google-trends/{topic}")
def google_trends_handler(topic: str):
    trends_data = obtener_datos_google_trends_semanal(topic)  # Usar 'topic' en lugar de 'palabra_clave'
    return trends_data.to_dict()

# Ejemplo de uso
palabra_clave = "Unemployment benefits"
datos = obtener_datos_google_trends_semanal(palabra_clave)
datos
# Out:
# Error al obtener datos de Google Trends: The request failed: Google returned a response with code 429
#             Unemployment benefits  isPartial
# date
# 2014-01-05                    0.0        0.0
# 2014-01-12                    NaN        NaN
# 2014-01-19                    NaN        NaN
# 2014-01-26                    NaN        NaN
# 2014-02-02                    0.0        0.0
# ...                           ...        ...
# 2024-02-04                    0.0        0.0
# 2024-02-11                    NaN        NaN
# 2024-02-18                    NaN        NaN
# 2024-02-25                    NaN        NaN
# 2024-03-03                    5.0        0.0
#
# [531 rows x 2 columns]

# %% [markdown]
# lo he mejoado con una finc
# AT: Austria
# BE: Belgium
# CH: Switzerland
# CY: Cyprus
# CZ: Czech Republic
# DE: Germany
# DK: Denmark
# EE: Estonia
# EL: Greece
# ES: Spain
# FI: Finland
# FR: France
# HU: Hungary
# IE: Ireland
# IS: Iceland
# IT: Italy
# LU: Luxembourg
# ME: Montenegro
# MT: Malta
# NL: Netherlands
# NO: Norway
# PL: Poland
# PT: Portugal
# SE: Sweden
# SI: Slovenia
# UK: United Kingdom que es ukraine en pytrends
# GB:United Kingdom
# LT: Lithuania
# LV: Latvia

# %%
#ES
import time
from pytrends.request import TrendReq
from fastapi import FastAPI
import pandas as pd

app = FastAPI()

def obtener_datos_google_trends_semanal(palabra_clave, pais='ES', fecha_inicio='2014-01-01', fecha_fin='2024-03-31'):
    try:
        pytrends = TrendReq(hl='es', tz=360)
        pytrends.build_payload(kw_list=[palabra_clave], timeframe=f'{fecha_inicio} {fecha_fin}', geo=pais)
        data = pytrends.interest_over_time()
        if data.empty:
            raise ValueError("No hay datos disponibles para la palabra clave y país proporcionados.")
        data_semanal = data.resample('W').mean()
        return data_semanal
    except Exception as e:
        print(f"Error al obtener datos de Google Trends: {e}")
        time.sleep(60)
        return obtener_datos_google_trends_semanal(palabra_clave, pais, fecha_inicio, fecha_fin)

@app.get("/google-trends/{topic}")
def google_trends_handler(topic: str, pais: str = 'ES', fecha_inicio: str = '2014-01-01', fecha_fin: str = '2024-03-31'):
    trends_data = obtener_datos_google_trends_semanal(topic, pais, fecha_inicio, fecha_fin)
    return trends_data.to_dict()

# Ejemplo de uso
palabra_clave = "Unemployment benefits"
datos = obtener_datos_google_trends_semanal(palabra_clave)
datos
# Out:
#             Unemployment benefits  isPartial
# date
# 2014-01-05                    0.0        0.0
# 2014-01-12                    NaN        NaN
# 2014-01-19                    NaN        NaN
# 2014-01-26                    NaN        NaN
# 2014-02-02                    0.0        0.0
# ...                           ...        ...
# 2024-02-04                   47.0        0.0
# 2024-02-11                    NaN        NaN
# 2024-02-18                    NaN        NaN
# 2024-02-25                    NaN        NaN
# 2024-03-03                   13.0        0.0
#
# [531 rows x 2 columns]

# %%
# CH  : switzerland


import time
from pytrends.request import TrendReq
from fastapi import FastAPI
import pandas as pd

app = FastAPI()

def obtener_datos_google_trends_semanal(palabra_clave, pais='CH', fecha_inicio='2014-01-01', fecha_fin='2024-03-31'):
    try:
        pytrends = TrendReq(hl='es', tz=360)
        pytrends.build_payload(kw_list=[palabra_clave], timeframe=f'{fecha_inicio} {fecha_fin}', geo=pais)
        data = pytrends.interest_over_time()
        if data.empty:
            raise ValueError("No hay datos disponibles para la palabra clave y país proporcionados.")
        data_semanal = data.resample('W').mean()
        return data_semanal
    except Exception as e:
        print(f"Error al obtener datos de Google Trends: {e}")
        time.sleep(60)
        return obtener_datos_google_trends_semanal(palabra_clave, pais, fecha_inicio, fecha_fin)

@app.get("/google-trends/{topic}")
def google_trends_handler(topic: str, pais: str = 'EL', fecha_inicio: str = '2014-01-01', fecha_fin: str = '2024-03-31'):
    try:
        trends_data = obtener_datos_google_trends_semanal(topic, pais, fecha_inicio, fecha_fin)
        return trends_data.to_dict()
    except ValueError as ve:
        return {"error": str(ve)}

# Ejemplo de uso
palabra_clave = "Unemployment benefits"
datos = obtener_datos_google_trends_semanal(palabra_clave)
datos
# Out:
#             Unemployment benefits  isPartial
# date
# 2014-01-05                    0.0        0.0
# 2014-01-12                    NaN        NaN
# 2014-01-19                    NaN        NaN
# 2014-01-26                    NaN        NaN
# 2014-02-02                    0.0        0.0
# ...                           ...        ...
# 2024-02-04                   54.0        0.0
# 2024-02-11                    NaN        NaN
# 2024-02-18                    NaN        NaN
# 2024-02-25                    NaN        NaN
# 2024-03-03                   18.0        0.0
#
# [531 rows x 2 columns]

# %%
# BE
import time
from pytrends.request import TrendReq
from fastapi import FastAPI
import pandas as pd

app = FastAPI()

def obtener_datos_google_trends_semanal(palabra_clave, pais='BE', fecha_inicio='2014-01-01', fecha_fin='2024-03-31'):
    try:
        pytrends = TrendReq(hl='es', tz=360)
        pytrends.build_payload(kw_list=[palabra_clave], timeframe=f'{fecha_inicio} {fecha_fin}', geo=pais)
        data = pytrends.interest_over_time()
        if data.empty:
            raise ValueError("No hay datos disponibles para la palabra clave y país proporcionados.")
        data_semanal = data.resample('W').mean()
        return data_semanal
    except Exception as e:
        print(f"Error al obtener datos de Google Trends: {e}")
        time.sleep(60)
        return obtener_datos_google_trends_semanal(palabra_clave, pais, fecha_inicio, fecha_fin)

@app.get("/google-trends/{topic}")
def google_trends_handler(topic: str, pais: str = 'EL', fecha_inicio: str = '2014-01-01', fecha_fin: str = '2024-03-31'):
    try:
        trends_data = obtener_datos_google_trends_semanal(topic, pais, fecha_inicio, fecha_fin)
        return trends_data.to_dict()
    except ValueError as ve:
        return {"error": str(ve)}

# Ejemplo de uso
palabra_clave = "Unemployment benefits"
datos = obtener_datos_google_trends_semanal(palabra_clave)
datos
# Out:
#             Unemployment benefits  isPartial
# date
# 2014-01-05                    0.0        0.0
# 2014-01-12                    NaN        NaN
# 2014-01-19                    NaN        NaN
# 2014-01-26                    NaN        NaN
# 2014-02-02                    0.0        0.0
# ...                           ...        ...
# 2024-02-04                   52.0        0.0
# 2024-02-11                    NaN        NaN
# 2024-02-18                    NaN        NaN
# 2024-02-25                    NaN        NaN
# 2024-03-03                   14.0        0.0
#
# [531 rows x 2 columns]

# %%
# trying AT

import time
from pytrends.request import TrendReq
from fastapi import FastAPI
import pandas as pd

app = FastAPI()

def obtener_datos_google_trends_semanal(palabra_clave, pais='AT', fecha_inicio='2014-01-01', fecha_fin='2024-03-31'):
    try:
        pytrends = TrendReq(hl='es', tz=360)
        pytrends.build_payload(kw_list=[palabra_clave], timeframe=f'{fecha_inicio} {fecha_fin}', geo=pais)
        data = pytrends.interest_over_time()
        if data.empty:
            raise ValueError("No hay datos disponibles para la palabra clave y país proporcionados.")
        data_semanal = data.resample('W').mean()
        return data_semanal
    except Exception as e:
        print(f"Error al obtener datos de Google Trends: {e}")
        time.sleep(60)
        return obtener_datos_google_trends_semanal(palabra_clave, pais, fecha_inicio, fecha_fin)

@app.get("/google-trends/{topic}")
def google_trends_handler(topic: str, pais: str = 'EL', fecha_inicio: str = '2014-01-01', fecha_fin: str = '2024-03-31'):
    try:
        trends_data = obtener_datos_google_trends_semanal(topic, pais, fecha_inicio, fecha_fin)
        return trends_data.to_dict()
    except ValueError as ve:
        return {"error": str(ve)}

# Ejemplo de uso
palabra_clave = "Unemployment benefits"
datos = obtener_datos_google_trends_semanal(palabra_clave)
datos
# Out:
#             Unemployment benefits  isPartial
# date
# 2014-01-05                    0.0        0.0
# 2014-01-12                    NaN        NaN
# 2014-01-19                    NaN        NaN
# 2014-01-26                    NaN        NaN
# 2014-02-02                    0.0        0.0
# ...                           ...        ...
# 2024-02-04                    0.0        0.0
# 2024-02-11                    NaN        NaN
# 2024-02-18                    NaN        NaN
# 2024-02-25                    NaN        NaN
# 2024-03-03                    9.0        0.0
#
# [531 rows x 2 columns]

# %%
# trying AT

import time
from pytrends.request import TrendReq
from fastapi import FastAPI
import pandas as pd

app = FastAPI()

def obtener_datos_google_trends_semanal(palabra_clave, pais='AT', fecha_inicio='2014-01-01', fecha_fin='2024-03-31'):
    try:
        pytrends = TrendReq(hl='es', tz=360)
        pytrends.build_payload(kw_list=[palabra_clave], timeframe=f'{fecha_inicio} {fecha_fin}', geo=pais)
        data = pytrends.interest_over_time()
        if data.empty:
            raise ValueError("No hay datos disponibles para la palabra clave y país proporcionados.")
        data_semanal = data.resample('W').mean()
        return data_semanal
    except Exception as e:
        print(f"Error al obtener datos de Google Trends: {e}")
        time.sleep(60)
        return obtener_datos_google_trends_semanal(palabra_clave, pais, fecha_inicio, fecha_fin)

@app.get("/google-trends/{topic}")
def google_trends_handler(topic: str, pais: str = 'EL', fecha_inicio: str = '2014-01-01', fecha_fin: str = '2024-03-31'):
    try:
        trends_data = obtener_datos_google_trends_semanal(topic, pais, fecha_inicio, fecha_fin)
        return trends_data.to_dict()
    except ValueError as ve:
        return {"error": str(ve)}

# Ejemplo de uso
palabra_clave = "Unemployment benefits"
datos = obtener_datos_google_trends_semanal(palabra_clave)
datos
# Out:
#             Unemployment benefits  isPartial
# date
# 2014-01-05                    0.0        0.0
# 2014-01-12                    NaN        NaN
# 2014-01-19                    NaN        NaN
# 2014-01-26                    NaN        NaN
# 2014-02-02                    0.0        0.0
# ...                           ...        ...
# 2024-02-04                    0.0        0.0
# 2024-02-11                    NaN        NaN
# 2024-02-18                    NaN        NaN
# 2024-02-25                    NaN        NaN
# 2024-03-03                    9.0        0.0
#
# [531 rows x 2 columns]

# %%
['AT', 'BE', 'CH', 'CY', 'CZ', 'DE', 'DK', 'EE', 'EL', 'ES',
       'FI', 'FR', 'HU', 'IE', 'IS', 'IT', 'LU', 'ME',
       'MT', 'NL', 'NO', 'PL', 'PT', 'SE', 'SI', 'UK',
        'LT', 'LV']
# Out:
# ['AT',
#  'BE',
#  'CH',
#  'CY',
#  'CZ',
#  'DE',
#  'DK',
#  'EE',
#  'EL',
#  'ES',
#  'FI',
#  'FR',
#  'HU',
#  'IE',
#  'IS',
#  'IT',
#  'LU',
#  'ME',
#  'MT',
#  'NL',
#  'NO',
#  'PL',
#  'PT',
#  'SE',
#  'SI',
#  'UK',
#  'LT',
#  'LV']

# %%
import time
from pytrends.request import TrendReq
from fastapi import FastAPI
import pandas as pd

app = FastAPI()

def obtener_datos_google_trends_semanal(palabra_clave, pais='CZ', fecha_inicio='2014-01-01', fecha_fin='2024-03-31'):
    try:
        pytrends = TrendReq(hl='es', tz=360)
        pytrends.build_payload(kw_list=[palabra_clave], timeframe=f'{fecha_inicio} {fecha_fin}', geo=pais)
        data = pytrends.interest_over_time()
        if data.empty:
            raise ValueError("No hay datos disponibles para la palabra clave y país proporcionados.")
        data_semanal = data.resample('W').mean()
        return data_semanal
    except Exception as e:
        print(f"Error al obtener datos de Google Trends: {e}")
        time.sleep(60)
        return obtener_datos_google_trends_semanal(palabra_clave, pais, fecha_inicio, fecha_fin)

@app.get("/google-trends/{topic}")
def google_trends_handler(topic: str, pais: str = 'CZ', fecha_inicio: str = '2014-01-01', fecha_fin: str = '2024-03-31'):
    try:
        trends_data = obtener_datos_google_trends_semanal(topic, pais, fecha_inicio, fecha_fin)
        return trends_data.to_dict()
    except ValueError as ve:
        return {"error": str(ve)}

# Ejemplo de uso
palabra_clave = "Unemployment benefits"
datos = obtener_datos_google_trends_semanal(palabra_clave)
datos
# Out:
#             Unemployment benefits  isPartial
# date
# 2014-01-05                    0.0        0.0
# 2014-01-12                    NaN        NaN
# 2014-01-19                    NaN        NaN
# 2014-01-26                    NaN        NaN
# 2014-02-02                    0.0        0.0
# ...                           ...        ...
# 2024-02-04                    0.0        0.0
# 2024-02-11                    NaN        NaN
# 2024-02-18                    NaN        NaN
# 2024-02-25                    NaN        NaN
# 2024-03-03                    3.0        0.0
#
# [531 rows x 2 columns]

# %%
import time
from pytrends.request import TrendReq
from fastapi import FastAPI
import pandas as pd

app = FastAPI()

def obtener_datos_google_trends_semanal(palabra_clave, pais='DE', fecha_inicio='2014-01-01', fecha_fin='2024-03-31'):
    try:
        pytrends = TrendReq(hl='es', tz=360)
        pytrends.build_payload(kw_list=[palabra_clave], timeframe=f'{fecha_inicio} {fecha_fin}', geo=pais)
        data = pytrends.interest_over_time()
        if data.empty:
            raise ValueError("No hay datos disponibles para la palabra clave y país proporcionados.")
        data_semanal = data.resample('W').mean()
        return data_semanal
    except Exception as e:
        print(f"Error al obtener datos de Google Trends: {e}")
        time.sleep(60)
        return obtener_datos_google_trends_semanal(palabra_clave, pais, fecha_inicio, fecha_fin)

@app.get("/google-trends/{topic}")
def google_trends_handler(topic: str, pais: str = 'DE', fecha_inicio: str = '2014-01-01', fecha_fin: str = '2024-03-31'):
    try:
        trends_data = obtener_datos_google_trends_semanal(topic, pais, fecha_inicio, fecha_fin)
        return trends_data.to_dict()
    except ValueError as ve:
        return {"error": str(ve)}

# Ejemplo de uso
palabra_clave = "Unemployment benefits"
datos = obtener_datos_google_trends_semanal(palabra_clave)
datos
# Out:
#             Unemployment benefits  isPartial
# date
# 2014-01-05                   49.0        0.0
# 2014-01-12                    NaN        NaN
# 2014-01-19                    NaN        NaN
# 2014-01-26                    NaN        NaN
# 2014-02-02                    0.0        0.0
# ...                           ...        ...
# 2024-02-04                  100.0        0.0
# 2024-02-11                    NaN        NaN
# 2024-02-18                    NaN        NaN
# 2024-02-25                    NaN        NaN
# 2024-03-03                   78.0        0.0
#
# [531 rows x 2 columns]

# %%
import time
from pytrends.request import TrendReq
from fastapi import FastAPI
import pandas as pd

app = FastAPI()


def obtener_datos_google_trends_semanal(palabra_clave, pais='DK', fecha_inicio='2014-01-01', fecha_fin='2024-03-31'):
    try:
        pytrends = TrendReq(hl='es', tz=360)
        pytrends.build_payload(kw_list=[palabra_clave], timeframe=f'{fecha_inicio} {fecha_fin}', geo=pais)
        data = pytrends.interest_over_time()
        if data.empty:
            raise ValueError("No hay datos disponibles para la palabra clave y país proporcionados.")
        data_semanal = data.resample('W').mean()
        return data_semanal
    except Exception as e:
        print(f"Error al obtener datos de Google Trends: {e}")
        time.sleep(60)
        return obtener_datos_google_trends_semanal(palabra_clave, pais, fecha_inicio, fecha_fin)

@app.get("/google-trends/{topic}")
def google_trends_handler(topic: str, pais: str = 'DK', fecha_inicio: str = '2014-01-01', fecha_fin: str = '2024-03-31'):
    try:
        trends_data = obtener_datos_google_trends_semanal(topic, pais, fecha_inicio, fecha_fin)
        return trends_data.to_dict()
    except ValueError as ve:
        return {"error": str(ve)}

# Ejemplo de uso
palabra_clave = "Unemployment benefits"
datos = obtener_datos_google_trends_semanal(palabra_clave)
datos
# Out:
#             Unemployment benefits  isPartial
# date
# 2014-01-05                   69.0        0.0
# 2014-01-12                    NaN        NaN
# 2014-01-19                    NaN        NaN
# 2014-01-26                    NaN        NaN
# 2014-02-02                    0.0        0.0
# ...                           ...        ...
# 2024-02-04                    0.0        0.0
# 2024-02-11                    NaN        NaN
# 2024-02-18                    NaN        NaN
# 2024-02-25                    NaN        NaN
# 2024-03-03                   11.0        0.0
#
# [531 rows x 2 columns]

# %%
import time
from pytrends.request import TrendReq
from fastapi import FastAPI
import pandas as pd

app = FastAPI()


def obtener_datos_google_trends_semanal(palabra_clave, pais='DK', fecha_inicio='2014-01-01', fecha_fin='2024-03-31'):
    try:
        pytrends = TrendReq(hl='es', tz=360)
        pytrends.build_payload(kw_list=[palabra_clave], timeframe=f'{fecha_inicio} {fecha_fin}', geo=pais)
        data = pytrends.interest_over_time()
        if data.empty:
            raise ValueError("No hay datos disponibles para la palabra clave y país proporcionados.")
        data_semanal = data.resample('W').mean()
        return data_semanal
    except Exception as e:
        print(f"Error al obtener datos de Google Trends: {e}")
        time.sleep(60)
        return obtener_datos_google_trends_semanal(palabra_clave, pais, fecha_inicio, fecha_fin)

@app.get("/google-trends/{topic}")
def google_trends_handler(topic: str, pais: str = 'DK', fecha_inicio: str = '2014-01-01', fecha_fin: str = '2024-03-31'):
    try:
        trends_data = obtener_datos_google_trends_semanal(topic, pais, fecha_inicio, fecha_fin)
        return trends_data.to_dict()
    except ValueError as ve:
        return {"error": str(ve)}

# Ejemplo de uso
palabra_clave = "Unemployment benefits"
datos = obtener_datos_google_trends_semanal(palabra_clave)
datos
# Out:
#             Unemployment benefits  isPartial
# date
# 2014-01-05                   69.0        0.0
# 2014-01-12                    NaN        NaN
# 2014-01-19                    NaN        NaN
# 2014-01-26                    NaN        NaN
# 2014-02-02                    0.0        0.0
# ...                           ...        ...
# 2024-02-04                    0.0        0.0
# 2024-02-11                    NaN        NaN
# 2024-02-18                    NaN        NaN
# 2024-02-25                    NaN        NaN
# 2024-03-03                   11.0        0.0
#
# [531 rows x 2 columns]

# %%
import time
from pytrends.request import TrendReq
from fastapi import FastAPI
import pandas as pd

app = FastAPI()


def obtener_datos_google_trends_semanal(palabra_clave, pais='FI', fecha_inicio='2014-01-01', fecha_fin='2024-03-31'):
    try:
        pytrends = TrendReq(hl='es', tz=360)
        pytrends.build_payload(kw_list=[palabra_clave], timeframe=f'{fecha_inicio} {fecha_fin}', geo=pais)
        data = pytrends.interest_over_time()
        if data.empty:
            raise ValueError("No hay datos disponibles para la palabra clave y país proporcionados.")
        data_semanal = data.resample('W').mean()
        return data_semanal
    except Exception as e:
        print(f"Error al obtener datos de Google Trends: {e}")
        time.sleep(60)
        return obtener_datos_google_trends_semanal(palabra_clave, pais, fecha_inicio, fecha_fin)

@app.get("/google-trends/{topic}")
def google_trends_handler(topic: str, pais: str = 'FI', fecha_inicio: str = '2014-01-01', fecha_fin: str = '2024-03-31'):
    try:
        trends_data = obtener_datos_google_trends_semanal(topic, pais, fecha_inicio, fecha_fin)
        return trends_data.to_dict()
    except ValueError as ve:
        return {"error": str(ve)}

# Ejemplo de uso
palabra_clave = "Unemployment benefits"
datos = obtener_datos_google_trends_semanal(palabra_clave)
datos
# Out:
#             Unemployment benefits  isPartial
# date
# 2014-01-05                    0.0        0.0
# 2014-01-12                    NaN        NaN
# 2014-01-19                    NaN        NaN
# 2014-01-26                    NaN        NaN
# 2014-02-02                    0.0        0.0
# ...                           ...        ...
# 2024-02-04                   79.0        0.0
# 2024-02-11                    NaN        NaN
# 2024-02-18                    NaN        NaN
# 2024-02-25                    NaN        NaN
# 2024-03-03                   23.0        0.0
#
# [531 rows x 2 columns]

# %%
import time
from pytrends.request import TrendReq
from fastapi import FastAPI
import pandas as pd

app = FastAPI()


def obtener_datos_google_trends_semanal(palabra_clave, pais='FR', fecha_inicio='2014-01-01', fecha_fin='2024-03-31'):
    try:
        pytrends = TrendReq(hl='es', tz=360)
        pytrends.build_payload(kw_list=[palabra_clave], timeframe=f'{fecha_inicio} {fecha_fin}', geo=pais)
        data = pytrends.interest_over_time()
        if data.empty:
            raise ValueError("No hay datos disponibles para la palabra clave y país proporcionados.")
        data_semanal = data.resample('W').mean()
        return data_semanal
    except Exception as e:
        print(f"Error al obtener datos de Google Trends: {e}")
        time.sleep(60)
        return obtener_datos_google_trends_semanal(palabra_clave, pais, fecha_inicio, fecha_fin)

@app.get("/google-trends/{topic}")
def google_trends_handler(topic: str, pais: str = 'FR', fecha_inicio: str = '2014-01-01', fecha_fin: str = '2024-03-31'):
    try:
        trends_data = obtener_datos_google_trends_semanal(topic, pais, fecha_inicio, fecha_fin)
        return trends_data.to_dict()
    except ValueError as ve:
        return {"error": str(ve)}

# Ejemplo de uso
palabra_clave = "Unemployment benefits"
datos = obtener_datos_google_trends_semanal(palabra_clave)
datos
# Out:
# Error al obtener datos de Google Trends: The request failed: Google returned a response with code 429
# Error al obtener datos de Google Trends: The request failed: Google returned a response with code 429
#             Unemployment benefits  isPartial
# date
# 2014-01-05                   67.0        0.0
# 2014-01-12                    NaN        NaN
# 2014-01-19                    NaN        NaN
# 2014-01-26                    NaN        NaN
# 2014-02-02                   66.0        0.0
# ...                           ...        ...
# 2024-02-04                    0.0        0.0
# 2024-02-11                    NaN        NaN
# 2024-02-18                    NaN        NaN
# 2024-02-25                    NaN        NaN
# 2024-03-03                   19.0        0.0
#
# [531 rows x 2 columns]

# %%
import time
from pytrends.request import TrendReq
from fastapi import FastAPI
import pandas as pd

app = FastAPI()


def obtener_datos_google_trends_semanal(palabra_clave, pais='HU', fecha_inicio='2014-01-01', fecha_fin='2024-03-31'):
    try:
        pytrends = TrendReq(hl='es', tz=360)
        pytrends.build_payload(kw_list=[palabra_clave], timeframe=f'{fecha_inicio} {fecha_fin}', geo=pais)
        data = pytrends.interest_over_time()
        if data.empty:
            raise ValueError("No hay datos disponibles para la palabra clave y país proporcionados.")
        data_semanal = data.resample('W').mean()
        return data_semanal
    except Exception as e:
        print(f"Error al obtener datos de Google Trends: {e}")
        time.sleep(60)
        return obtener_datos_google_trends_semanal(palabra_clave, pais, fecha_inicio, fecha_fin)

@app.get("/google-trends/{topic}")
def google_trends_handler(topic: str, pais: str = 'HU', fecha_inicio: str = '2014-01-01', fecha_fin: str = '2024-03-31'):
    try:
        trends_data = obtener_datos_google_trends_semanal(topic, pais, fecha_inicio, fecha_fin)
        return trends_data.to_dict()
    except ValueError as ve:
        return {"error": str(ve)}

# Ejemplo de uso
palabra_clave = "Unemployment benefits"
datos = obtener_datos_google_trends_semanal(palabra_clave)
datos
# Out:
#             Unemployment benefits  isPartial
# date
# 2014-01-05                    0.0        0.0
# 2014-01-12                    NaN        NaN
# 2014-01-19                    NaN        NaN
# 2014-01-26                    NaN        NaN
# 2014-02-02                    0.0        0.0
# ...                           ...        ...
# 2024-02-04                    0.0        0.0
# 2024-02-11                    NaN        NaN
# 2024-02-18                    NaN        NaN
# 2024-02-25                    NaN        NaN
# 2024-03-03                    0.0        0.0
#
# [531 rows x 2 columns]

# %%
import time
from pytrends.request import TrendReq
from fastapi import FastAPI
import pandas as pd

app = FastAPI()

def obtener_datos_google_trends_semanal(palabra_clave, pais='IE', fecha_inicio='2014-01-01', fecha_fin='2024-03-31'):
    try:
        pytrends = TrendReq(hl='es', tz=360)
        pytrends.build_payload(kw_list=[palabra_clave], timeframe=f'{fecha_inicio} {fecha_fin}', geo=pais)
        data = pytrends.interest_over_time()
        if data.empty:
            raise ValueError("No hay datos disponibles para la palabra clave y país proporcionados.")
        data_semanal = data.resample('W').mean()
        return data_semanal
    except Exception as e:
        print(f"Error al obtener datos de Google Trends: {e}")
        time.sleep(60)
        return obtener_datos_google_trends_semanal(palabra_clave, pais, fecha_inicio, fecha_fin)

@app.get("/google-trends/{topic}")
def google_trends_handler(topic: str, pais: str = 'IE', fecha_inicio: str = '2014-01-01', fecha_fin: str = '2024-03-31'):
    try:
        trends_data = obtener_datos_google_trends_semanal(topic, pais, fecha_inicio, fecha_fin)
        return trends_data.to_dict()
    except ValueError as ve:
        return {"error": str(ve)}

# Ejemplo de uso
palabra_clave = "Unemployment benefits"
datos = obtener_datos_google_trends_semanal(palabra_clave)
datos
# Out:
# Error al obtener datos de Google Trends: The request failed: Google returned a response with code 429
# Error al obtener datos de Google Trends: The request failed: Google returned a response with code 429
# Error al obtener datos de Google Trends: The request failed: Google returned a response with code 429
# Error al obtener datos de Google Trends: The request failed: Google returned a response with code 429
# Error al obtener datos de Google Trends: The request failed: Google returned a response with code 429
# Error al obtener datos de Google Trends: The request failed: Google returned a response with code 429
#             Unemployment benefits  isPartial
# date
# 2014-01-05                   20.0        0.0
# 2014-01-12                    NaN        NaN
# 2014-01-19                    NaN        NaN
# 2014-01-26                    NaN        NaN
# 2014-02-02                   22.0        0.0
# ...                           ...        ...
# ...

# %%
import time
from pytrends.request import TrendReq
from fastapi import FastAPI
import pandas as pd

app = FastAPI()


def obtener_datos_google_trends_semanal(palabra_clave, pais='IS', fecha_inicio='2014-01-01', fecha_fin='2024-03-31'):
    try:
        pytrends = TrendReq(hl='es', tz=360)
        pytrends.build_payload(kw_list=[palabra_clave], timeframe=f'{fecha_inicio} {fecha_fin}', geo=pais)
        data = pytrends.interest_over_time()
        if data.empty:
            raise ValueError("No hay datos disponibles para la palabra clave y país proporcionados.")
        data_semanal = data.resample('W').mean()
        return data_semanal
    except Exception as e:
        print(f"Error al obtener datos de Google Trends: {e}")
        time.sleep(60)
        return obtener_datos_google_trends_semanal(palabra_clave, pais, fecha_inicio, fecha_fin)

@app.get("/google-trends/{topic}")
def google_trends_handler(topic: str, pais: str = 'IS', fecha_inicio: str = '2014-01-01', fecha_fin: str = '2024-03-31'):
    try:
        trends_data = obtener_datos_google_trends_semanal(topic, pais, fecha_inicio, fecha_fin)
        return trends_data.to_dict()
    except ValueError as ve:
        return {"error": str(ve)}

# Ejemplo de uso
palabra_clave = "Unemployment benefits"
datos = obtener_datos_google_trends_semanal(palabra_clave)

datos
# Out:
#             Unemployment benefits  isPartial
# date
# 2014-01-05                    0.0        0.0
# 2014-01-12                    NaN        NaN
# 2014-01-19                    NaN        NaN
# 2014-01-26                    NaN        NaN
# 2014-02-02                    0.0        0.0
# ...                           ...        ...
# 2024-02-04                    0.0        0.0
# 2024-02-11                    NaN        NaN
# 2024-02-18                    NaN        NaN
# 2024-02-25                    NaN        NaN
# 2024-03-03                    5.0        0.0
#
# [531 rows x 2 columns]

# %%
import time
from pytrends.request import TrendReq
from fastapi import FastAPI
import pandas as pd

app = FastAPI()


def obtener_datos_google_trends_semanal(palabra_clave, pais='IT', fecha_inicio='2014-01-01', fecha_fin='2024-03-31'):
    try:
        pytrends = TrendReq(hl='es', tz=360)
        pytrends.build_payload(kw_list=[palabra_clave], timeframe=f'{fecha_inicio} {fecha_fin}', geo=pais)
        data = pytrends.interest_over_time()
        if data.empty:
            raise ValueError("No hay datos disponibles para la palabra clave y país proporcionados.")
        data_semanal = data.resample('W').mean()
        return data_semanal
    except Exception as e:
        print(f"Error al obtener datos de Google Trends: {e}")
        time.sleep(60)
        return obtener_datos_google_trends_semanal(palabra_clave, pais, fecha_inicio, fecha_fin)

@app.get("/google-trends/{topic}")
def google_trends_handler(topic: str, pais: str = 'IT', fecha_inicio: str = '2014-01-01', fecha_fin: str = '2024-03-31'):
    try:
        trends_data = obtener_datos_google_trends_semanal(topic, pais, fecha_inicio, fecha_fin)
        return trends_data.to_dict()
    except ValueError as ve:
        return {"error": str(ve)}

# Ejemplo de uso
palabra_clave = "Unemployment benefits"
datos = obtener_datos_google_trends_semanal(palabra_clave)
datos
# Out:
#             Unemployment benefits  isPartial
# date
# 2014-01-05                    0.0        0.0
# 2014-01-12                    NaN        NaN
# 2014-01-19                    NaN        NaN
# 2014-01-26                    NaN        NaN
# 2014-02-02                    0.0        0.0
# ...                           ...        ...
# 2024-02-04                    0.0        0.0
# 2024-02-11                    NaN        NaN
# 2024-02-18                    NaN        NaN
# 2024-02-25                    NaN        NaN
# 2024-03-03                   11.0        0.0
#
# [531 rows x 2 columns]

# %%
import time
from pytrends.request import TrendReq
from fastapi import FastAPI
import pandas as pd

app = FastAPI()


def obtener_datos_google_trends_semanal(palabra_clave, pais='LU', fecha_inicio='2014-01-01', fecha_fin='2024-03-31'):
    try:
        pytrends = TrendReq(hl='es', tz=360)
        pytrends.build_payload(kw_list=[palabra_clave], timeframe=f'{fecha_inicio} {fecha_fin}', geo=pais)
        data = pytrends.interest_over_time()
        if data.empty:
            raise ValueError("No hay datos disponibles para la palabra clave y país proporcionados.")
        data_semanal = data.resample('W').mean()
        return data_semanal
    except Exception as e:
        print(f"Error al obtener datos de Google Trends: {e}")
        time.sleep(60)
        return obtener_datos_google_trends_semanal(palabra_clave, pais, fecha_inicio, fecha_fin)

@app.get("/google-trends/{topic}")
def google_trends_handler(topic: str, pais: str = 'LU', fecha_inicio: str = '2014-01-01', fecha_fin: str = '2024-03-31'):
    try:
        trends_data = obtener_datos_google_trends_semanal(topic, pais, fecha_inicio, fecha_fin)
        return trends_data.to_dict()
    except ValueError as ve:
        return {"error": str(ve)}

# Ejemplo de uso
palabra_clave = "Unemployment benefits"
datos = obtener_datos_google_trends_semanal(palabra_clave)
datos
# Out:
#             Unemployment benefits  isPartial
# date
# 2014-01-05                    0.0        0.0
# 2014-01-12                    NaN        NaN
# 2014-01-19                    NaN        NaN
# 2014-01-26                    NaN        NaN
# 2014-02-02                    0.0        0.0
# ...                           ...        ...
# 2024-02-04                    0.0        0.0
# 2024-02-11                    NaN        NaN
# 2024-02-18                    NaN        NaN
# 2024-02-25                    NaN        NaN
# 2024-03-03                   11.0        0.0
#
# [531 rows x 2 columns]

# %%
import time
from pytrends.request import TrendReq
from fastapi import FastAPI
import pandas as pd

app = FastAPI()


def obtener_datos_google_trends_semanal(palabra_clave, pais='ME', fecha_inicio='2014-01-01', fecha_fin='2024-03-31'):
    try:
        pytrends = TrendReq(hl='es', tz=360)
        pytrends.build_payload(kw_list=[palabra_clave], timeframe=f'{fecha_inicio} {fecha_fin}', geo=pais)
        data = pytrends.interest_over_time()
        if data.empty:
            raise ValueError("No hay datos disponibles para la palabra clave y país proporcionados.")
        data_semanal = data.resample('W').mean()
        return data_semanal
    except Exception as e:
        print(f"Error al obtener datos de Google Trends: {e}")
        time.sleep(60)
        return obtener_datos_google_trends_semanal(palabra_clave, pais, fecha_inicio, fecha_fin)

@app.get("/google-trends/{topic}")
def google_trends_handler(topic: str, pais: str = 'ME', fecha_inicio: str = '2014-01-01', fecha_fin: str = '2024-03-31'):
    try:
        trends_data = obtener_datos_google_trends_semanal(topic, pais, fecha_inicio, fecha_fin)
        return trends_data.to_dict()
    except ValueError as ve:
        return {"error": str(ve)}

# Ejemplo de uso
palabra_clave = "Unemployment benefits"
datos = obtener_datos_google_trends_semanal(palabra_clave)
datos
# Out:
#             Unemployment benefits  isPartial
# date
# 2014-01-05                    0.0        0.0
# 2014-01-12                    NaN        NaN
# 2014-01-19                    NaN        NaN
# 2014-01-26                    NaN        NaN
# 2014-02-02                    0.0        0.0
# ...                           ...        ...
# 2024-02-04                    0.0        0.0
# 2024-02-11                    NaN        NaN
# 2024-02-18                    NaN        NaN
# 2024-02-25                    NaN        NaN
# 2024-03-03                    0.0        0.0
#
# [531 rows x 2 columns]

# %%
import time
from pytrends.request import TrendReq
from fastapi import FastAPI
import pandas as pd

app = FastAPI()

def obtener_datos_google_trends_semanal(palabra_clave, pais='MT', fecha_inicio='2014-01-01', fecha_fin='2024-03-31'):
    try:
        pytrends = TrendReq(hl='es', tz=360)
        pytrends.build_payload(kw_list=[palabra_clave], timeframe=f'{fecha_inicio} {fecha_fin}', geo=pais)
        data = pytrends.interest_over_time()
        if data.empty:
            raise ValueError("No hay datos disponibles para la palabra clave y país proporcionados.")
        data_semanal = data.resample('W').mean()
        return data_semanal
    except Exception as e:
        print(f"Error al obtener datos de Google Trends: {e}")
        time.sleep(60)
        return obtener_datos_google_trends_semanal(palabra_clave, pais, fecha_inicio, fecha_fin)

@app.get("/google-trends/{topic}")
def google_trends_handler(topic: str, pais: str = 'MT', fecha_inicio: str = '2014-01-01', fecha_fin: str = '2024-03-31'):
    try:
        trends_data = obtener_datos_google_trends_semanal(topic, pais, fecha_inicio, fecha_fin)
        return trends_data.to_dict()
    except ValueError as ve:
        return {"error": str(ve)}

# Ejemplo de uso
palabra_clave = "Unemployment benefits"
datos = obtener_datos_google_trends_semanal(palabra_clave)
datos
# Out:
# Error al obtener datos de Google Trends: The request failed: Google returned a response with code 429
#             Unemployment benefits  isPartial
# date
# 2014-01-05                    0.0        0.0
# 2014-01-12                    NaN        NaN
# 2014-01-19                    NaN        NaN
# 2014-01-26                    NaN        NaN
# 2014-02-02                    0.0        0.0
# ...                           ...        ...
# 2024-02-04                    0.0        0.0
# 2024-02-11                    NaN        NaN
# 2024-02-18                    NaN        NaN
# 2024-02-25                    NaN        NaN
# 2024-03-03                    5.0        0.0
#
# [531 rows x 2 columns]

# %%
import time
from pytrends.request import TrendReq
from fastapi import FastAPI
import pandas as pd

app = FastAPI()


def obtener_datos_google_trends_semanal(palabra_clave, pais='NL', fecha_inicio='2014-01-01', fecha_fin='2024-03-31'):
    try:
        pytrends = TrendReq(hl='es', tz=360)
        pytrends.build_payload(kw_list=[palabra_clave], timeframe=f'{fecha_inicio} {fecha_fin}', geo=pais)
        data = pytrends.interest_over_time()
        if data.empty:
            raise ValueError("No hay datos disponibles para la palabra clave y país proporcionados.")
        data_semanal = data.resample('W').mean()
        return data_semanal
    except Exception as e:
        print(f"Error al obtener datos de Google Trends: {e}")
        time.sleep(60)
        return obtener_datos_google_trends_semanal(palabra_clave, pais, fecha_inicio, fecha_fin)

@app.get("/google-trends/{topic}")
def google_trends_handler(topic: str, pais: str = 'LV', fecha_inicio: str = '2014-01-01', fecha_fin: str = '2024-03-31'):
    try:
        trends_data = obtener_datos_google_trends_semanal(topic, pais, fecha_inicio, fecha_fin)
        return trends_data.to_dict()
    except ValueError as ve:
        return {"error": str(ve)}

# Ejemplo de uso
palabra_clave = "Unemployment benefits"
datos = obtener_datos_google_trends_semanal(palabra_clave)
datos
# Out:
#             Unemployment benefits  isPartial
# date
# 2014-01-05                   42.0        0.0
# 2014-01-12                    NaN        NaN
# 2014-01-19                    NaN        NaN
# 2014-01-26                    NaN        NaN
# 2014-02-02                    0.0        0.0
# ...                           ...        ...
# 2024-02-04                  100.0        0.0
# 2024-02-11                    NaN        NaN
# 2024-02-18                    NaN        NaN
# 2024-02-25                    NaN        NaN
# 2024-03-03                   77.0        0.0
#
# [531 rows x 2 columns]

# %%
import time
from pytrends.request import TrendReq
from fastapi import FastAPI
import pandas as pd

app = FastAPI()


def obtener_datos_google_trends_semanal(palabra_clave, pais='NO', fecha_inicio='2014-01-01', fecha_fin='2024-03-31'):
    try:
        pytrends = TrendReq(hl='es', tz=360)
        pytrends.build_payload(kw_list=[palabra_clave], timeframe=f'{fecha_inicio} {fecha_fin}', geo=pais)
        data = pytrends.interest_over_time()
        if data.empty:
            raise ValueError("No hay datos disponibles para la palabra clave y país proporcionados.")
        data_semanal = data.resample('W').mean()
        return data_semanal
    except Exception as e:
        print(f"Error al obtener datos de Google Trends: {e}")
        time.sleep(60)
        return obtener_datos_google_trends_semanal(palabra_clave, pais, fecha_inicio, fecha_fin)

@app.get("/google-trends/{topic}")
def google_trends_handler(topic: str, pais: str = 'NO', fecha_inicio: str = '2014-01-01', fecha_fin: str = '2024-03-31'):
    try:
        trends_data = obtener_datos_google_trends_semanal(topic, pais, fecha_inicio, fecha_fin)
        return trends_data.to_dict()
    except ValueError as ve:
        return {"error": str(ve)}

# Ejemplo de uso
palabra_clave = "Unemployment benefits"
datos = obtener_datos_google_trends_semanal(palabra_clave)
datos
# Out:
# Error al obtener datos de Google Trends: The request failed: Google returned a response with code 429
#             Unemployment benefits  isPartial
# date
# 2014-01-05                    0.0        0.0
# 2014-01-12                    NaN        NaN
# 2014-01-19                    NaN        NaN
# 2014-01-26                    NaN        NaN
# 2014-02-02                  100.0        0.0
# ...                           ...        ...
# 2024-02-04                    0.0        0.0
# 2024-02-11                    NaN        NaN
# 2024-02-18                    NaN        NaN
# 2024-02-25                    NaN        NaN
# 2024-03-03                    4.0        0.0
#
# [531 rows x 2 columns]

# %%
import time
from pytrends.request import TrendReq
from fastapi import FastAPI
import pandas as pd

app = FastAPI()


def obtener_datos_google_trends_semanal(palabra_clave, pais='PL', fecha_inicio='2014-01-01', fecha_fin='2024-03-31'):
    try:
        pytrends = TrendReq(hl='es', tz=360)
        pytrends.build_payload(kw_list=[palabra_clave], timeframe=f'{fecha_inicio} {fecha_fin}', geo=pais)
        data = pytrends.interest_over_time()
        if data.empty:
            raise ValueError("No hay datos disponibles para la palabra clave y país proporcionados.")
        data_semanal = data.resample('W').mean()
        return data_semanal
    except Exception as e:
        print(f"Error al obtener datos de Google Trends: {e}")
        time.sleep(60)
        return obtener_datos_google_trends_semanal(palabra_clave, pais, fecha_inicio, fecha_fin)

@app.get("/google-trends/{topic}")
def google_trends_handler(topic: str, pais: str = 'PL', fecha_inicio: str = '2014-01-01', fecha_fin: str = '2024-03-31'):
    try:
        trends_data = obtener_datos_google_trends_semanal(topic, pais, fecha_inicio, fecha_fin)
        return trends_data.to_dict()
    except ValueError as ve:
        return {"error": str(ve)}

# Ejemplo de uso
palabra_clave = "Unemployment benefits"
datos = obtener_datos_google_trends_semanal(palabra_clave)
datos
# Out:
# Error al obtener datos de Google Trends: The request failed: Google returned a response with code 429
# Error al obtener datos de Google Trends: The request failed: Google returned a response with code 429
# Error al obtener datos de Google Trends: The request failed: Google returned a response with code 429
# Error al obtener datos de Google Trends: The request failed: Google returned a response with code 429
#             Unemployment benefits  isPartial
# date
# 2014-01-05                    0.0        0.0
# 2014-01-12                    NaN        NaN
# 2014-01-19                    NaN        NaN
# 2014-01-26                    NaN        NaN
# 2014-02-02                    0.0        0.0
# ...                           ...        ...
# 2024-02-04                    0.0        0.0
# 2024-02-11                    NaN        NaN
# 2024-02-18                    NaN        NaN
# 2024-02-25                    NaN        NaN
# 2024-03-03                    6.0        0.0
#
# ...

# %%
import time
from pytrends.request import TrendReq
from fastapi import FastAPI
import pandas as pd

app = FastAPI()


def obtener_datos_google_trends_semanal(palabra_clave, pais='PT', fecha_inicio='2014-01-01', fecha_fin='2024-03-31'):
    try:
        pytrends = TrendReq(hl='es', tz=360)
        pytrends.build_payload(kw_list=[palabra_clave], timeframe=f'{fecha_inicio} {fecha_fin}', geo=pais)
        data = pytrends.interest_over_time()
        if data.empty:
            raise ValueError("No hay datos disponibles para la palabra clave y país proporcionados.")
        data_semanal = data.resample('W').mean()
        return data_semanal
    except Exception as e:
        print(f"Error al obtener datos de Google Trends: {e}")
        time.sleep(60)
        return obtener_datos_google_trends_semanal(palabra_clave, pais, fecha_inicio, fecha_fin)

@app.get("/google-trends/{topic}")
def google_trends_handler(topic: str, pais: str = 'PT', fecha_inicio: str = '2014-01-01', fecha_fin: str = '2024-03-31'):
    try:
        trends_data = obtener_datos_google_trends_semanal(topic, pais, fecha_inicio, fecha_fin)
        return trends_data.to_dict()
    except ValueError as ve:
        return {"error": str(ve)}

# Ejemplo de uso
palabra_clave = "Unemployment benefits"
datos = obtener_datos_google_trends_semanal(palabra_clave)
datos
# Out:
#             Unemployment benefits  isPartial
# date
# 2014-01-05                    0.0        0.0
# 2014-01-12                    NaN        NaN
# 2014-01-19                    NaN        NaN
# 2014-01-26                    NaN        NaN
# 2014-02-02                    0.0        0.0
# ...                           ...        ...
# 2024-02-04                    0.0        0.0
# 2024-02-11                    NaN        NaN
# 2024-02-18                    NaN        NaN
# 2024-02-25                    NaN        NaN
# 2024-03-03                    7.0        0.0
#
# [531 rows x 2 columns]

# %%
import time
from pytrends.request import TrendReq
from fastapi import FastAPI
import pandas as pd

app = FastAPI()


def obtener_datos_google_trends_semanal(palabra_clave, pais='SE', fecha_inicio='2014-01-01', fecha_fin='2024-03-31'):
    try:
        pytrends = TrendReq(hl='es', tz=360)
        pytrends.build_payload(kw_list=[palabra_clave], timeframe=f'{fecha_inicio} {fecha_fin}', geo=pais)
        data = pytrends.interest_over_time()
        if data.empty:
            raise ValueError("No hay datos disponibles para la palabra clave y país proporcionados.")
        data_semanal = data.resample('W').mean()
        return data_semanal
    except Exception as e:
        print(f"Error al obtener datos de Google Trends: {e}")
        time.sleep(60)
        return obtener_datos_google_trends_semanal(palabra_clave, pais, fecha_inicio, fecha_fin)

@app.get("/google-trends/{topic}")
def google_trends_handler(topic: str, pais: str = 'SE', fecha_inicio: str = '2014-01-01', fecha_fin: str = '2024-03-31'):
    try:
        trends_data = obtener_datos_google_trends_semanal(topic, pais, fecha_inicio, fecha_fin)
        return trends_data.to_dict()
    except ValueError as ve:
        return {"error": str(ve)}

# Ejemplo de uso
palabra_clave = "Unemployment benefits"
datos = obtener_datos_google_trends_semanal(palabra_clave)
datos
# Out:
#             Unemployment benefits  isPartial
# date
# 2014-01-05                    0.0        0.0
# 2014-01-12                    NaN        NaN
# 2014-01-19                    NaN        NaN
# 2014-01-26                    NaN        NaN
# 2014-02-02                    0.0        0.0
# ...                           ...        ...
# 2024-02-04                    0.0        0.0
# 2024-02-11                    NaN        NaN
# 2024-02-18                    NaN        NaN
# 2024-02-25                    NaN        NaN
# 2024-03-03                   13.0        0.0
#
# [531 rows x 2 columns]

# %%
import time
from pytrends.request import TrendReq
from fastapi import FastAPI
import pandas as pd

app = FastAPI()


def obtener_datos_google_trends_semanal(palabra_clave, pais='SI', fecha_inicio='2014-01-01', fecha_fin='2024-03-31'):
    try:
        pytrends = TrendReq(hl='es', tz=360)
        pytrends.build_payload(kw_list=[palabra_clave], timeframe=f'{fecha_inicio} {fecha_fin}', geo=pais)
        data = pytrends.interest_over_time()
        if data.empty:
            raise ValueError("No hay datos disponibles para la palabra clave y país proporcionados.")
        data_semanal = data.resample('W').mean()
        return data_semanal
    except Exception as e:
        print(f"Error al obtener datos de Google Trends: {e}")
        time.sleep(60)
        return obtener_datos_google_trends_semanal(palabra_clave, pais, fecha_inicio, fecha_fin)

@app.get("/google-trends/{topic}")
def google_trends_handler(topic: str, pais: str = 'SI', fecha_inicio: str = '2014-01-01', fecha_fin: str = '2024-03-31'):
    try:
        trends_data = obtener_datos_google_trends_semanal(topic, pais, fecha_inicio, fecha_fin)
        return trends_data.to_dict()
    except ValueError as ve:
        return {"error": str(ve)}

# Ejemplo de uso
palabra_clave = "Unemployment benefits"
datos = obtener_datos_google_trends_semanal(palabra_clave)
datos
# Out:
#             Unemployment benefits  isPartial
# date
# 2014-01-05                    0.0        0.0
# 2014-01-12                    NaN        NaN
# 2014-01-19                    NaN        NaN
# 2014-01-26                    NaN        NaN
# 2014-02-02                    0.0        0.0
# ...                           ...        ...
# 2024-02-04                    0.0        0.0
# 2024-02-11                    NaN        NaN
# 2024-02-18                    NaN        NaN
# 2024-02-25                    NaN        NaN
# 2024-03-03                    0.0        0.0
#
# [531 rows x 2 columns]

# %%
#errror de 400
# probably it take it as ukrain not as U.K : united kigdom  of eurostat so i think uk we should delted it


import time
from pytrends.request import TrendReq
from fastapi import FastAPI
import pandas as pd

app = FastAPI()


def obtener_datos_google_trends_semanal(palabra_clave, pais='UK', fecha_inicio='2014-01-01', fecha_fin='2024-03-31'):
    try:
        pytrends = TrendReq(hl='es', tz=360)
        pytrends.build_payload(kw_list=[palabra_clave], timeframe=f'{fecha_inicio} {fecha_fin}', geo=pais)
        data = pytrends.interest_over_time()
        if data.empty:
            raise ValueError("No hay datos disponibles para la palabra clave y país proporcionados.")
        data_semanal = data.resample('W').mean()
        return data_semanal
    except Exception as e:
        print(f"Error al obtener datos de Google Trends: {e}")
        time.sleep(60)
        return obtener_datos_google_trends_semanal(palabra_clave, pais, fecha_inicio, fecha_fin)

@app.get("/google-trends/{topic}")
def google_trends_handler(topic: str, pais: str = 'UK', fecha_inicio: str = '2014-01-01', fecha_fin: str = '2024-03-31'):
    try:
        trends_data = obtener_datos_google_trends_semanal(topic, pais, fecha_inicio, fecha_fin)
        return trends_data.to_dict()
    except ValueError as ve:
        return {"error": str(ve)}

# Ejemplo de uso
palabra_clave = "Unemployment benefits"
datos = obtener_datos_google_trends_semanal(palabra_clave)
datos
# Out:
# Error al obtener datos de Google Trends: The request failed: Google returned a response with code 400
# Error al obtener datos de Google Trends: The request failed: Google returned a response with code 400
# Error al obtener datos de Google Trends: The request failed: Google returned a response with code 400
# Error al obtener datos de Google Trends: The request failed: Google returned a response with code 400
# ---------------------------------------------------------------------------
# ResponseError                             Traceback (most recent call last)
# <ipython-input-116-dd90110d671b> in obtener_datos_google_trends_semanal(palabra_clave, pais, fecha_inicio, fecha_fin)
#      15         pytrends = TrendReq(hl='es', tz=360)
# ---> 16         pytrends.build_payload(kw_list=[palabra_clave], timeframe=f'{fecha_inicio} {fecha_fin}', geo=pais)
#      17         data = pytrends.interest_over_time()
#
# ...

# %%
import time
from pytrends.request import TrendReq
from fastapi import FastAPI
import pandas as pd

app = FastAPI()


def obtener_datos_google_trends_semanal(palabra_clave, pais='LT', fecha_inicio='2014-01-01', fecha_fin='2024-03-31'):
    try:
        pytrends = TrendReq(hl='es', tz=360)
        pytrends.build_payload(kw_list=[palabra_clave], timeframe=f'{fecha_inicio} {fecha_fin}', geo=pais)
        data = pytrends.interest_over_time()
        if data.empty:
            raise ValueError("No hay datos disponibles para la palabra clave y país proporcionados.")
        data_semanal = data.resample('W').mean()
        return data_semanal
    except Exception as e:
        print(f"Error al obtener datos de Google Trends: {e}")
        time.sleep(60)
        return obtener_datos_google_trends_semanal(palabra_clave, pais, fecha_inicio, fecha_fin)

@app.get("/google-trends/{topic}")
def google_trends_handler(topic: str, pais: str = 'LT', fecha_inicio: str = '2014-01-01', fecha_fin: str = '2024-03-31'):
    try:
        trends_data = obtener_datos_google_trends_semanal(topic, pais, fecha_inicio, fecha_fin)
        return trends_data.to_dict()
    except ValueError as ve:
        return {"error": str(ve)}

# Ejemplo de uso
palabra_clave = "Unemployment benefits"
datos = obtener_datos_google_trends_semanal(palabra_clave)
datos
# Out:
# Error al obtener datos de Google Trends: The request failed: Google returned a response with code 429
# Error al obtener datos de Google Trends: The request failed: Google returned a response with code 429
#             Unemployment benefits  isPartial
# date
# 2014-01-05                    0.0        0.0
# 2014-01-12                    NaN        NaN
# 2014-01-19                    NaN        NaN
# 2014-01-26                    NaN        NaN
# 2014-02-02                    0.0        0.0
# ...                           ...        ...
# 2024-02-04                    0.0        0.0
# 2024-02-11                    NaN        NaN
# 2024-02-18                    NaN        NaN
# 2024-02-25                    NaN        NaN
# 2024-03-03                    3.0        0.0
#
# [531 rows x 2 columns]

# %%
import time
from pytrends.request import TrendReq
from fastapi import FastAPI
import pandas as pd

app = FastAPI()


def obtener_datos_google_trends_semanal(palabra_clave, pais='LV', fecha_inicio='2014-01-01', fecha_fin='2024-03-31'):
    try:
        pytrends = TrendReq(hl='es', tz=360)
        pytrends.build_payload(kw_list=[palabra_clave], timeframe=f'{fecha_inicio} {fecha_fin}', geo=pais)
        data = pytrends.interest_over_time()
        if data.empty:
            raise ValueError("No hay datos disponibles para la palabra clave y país proporcionados.")
        data_semanal = data.resample('W').mean()
        return data_semanal
    except Exception as e:
        print(f"Error al obtener datos de Google Trends: {e}")
        time.sleep(60)
        return obtener_datos_google_trends_semanal(palabra_clave, pais, fecha_inicio, fecha_fin)

@app.get("/google-trends/{topic}")
def google_trends_handler(topic: str, pais: str = 'LV', fecha_inicio: str = '2014-01-01', fecha_fin: str = '2024-03-31'):
    try:
        trends_data = obtener_datos_google_trends_semanal(topic, pais, fecha_inicio, fecha_fin)
        return trends_data.to_dict()
    except ValueError as ve:
        return {"error": str(ve)}

# Ejemplo de uso
palabra_clave = "Unemployment benefits"
datos = obtener_datos_google_trends_semanal(palabra_clave)
datos
# Out:
# Error al obtener datos de Google Trends: The request failed: Google returned a response with code 429
#             Unemployment benefits  isPartial
# date
# 2014-01-05                    0.0        0.0
# 2014-01-12                    NaN        NaN
# 2014-01-19                    NaN        NaN
# 2014-01-26                    NaN        NaN
# 2014-02-02                    0.0        0.0
# ...                           ...        ...
# 2024-02-04                    0.0        0.0
# 2024-02-11                    NaN        NaN
# 2024-02-18                    NaN        NaN
# 2024-02-25                    NaN        NaN
# 2024-03-03                    0.0        0.0
#
# [531 rows x 2 columns]

# %%
import time
from pytrends.request import TrendReq
from fastapi import FastAPI
import pandas as pd

app = FastAPI()


def obtener_datos_google_trends_semanal(palabra_clave, pais='LV', fecha_inicio='2014-01-01', fecha_fin='2024-03-31'):
    try:
        pytrends = TrendReq(hl='es', tz=360)
        pytrends.build_payload(kw_list=[palabra_clave], timeframe=f'{fecha_inicio} {fecha_fin}', geo=pais)
        data = pytrends.interest_over_time()
        if data.empty:
            raise ValueError("No hay datos disponibles para la palabra clave y país proporcionados.")
        data_semanal = data.resample('W').mean()
        return data_semanal
    except Exception as e:
        print(f"Error al obtener datos de Google Trends: {e}")
        time.sleep(60)
        return obtener_datos_google_trends_semanal(palabra_clave, pais, fecha_inicio, fecha_fin)

@app.get("/google-trends/{topic}")
def google_trends_handler(topic: str, pais: str = 'LV', fecha_inicio: str = '2014-01-01', fecha_fin: str = '2024-03-31'):
    try:
        trends_data = obtener_datos_google_trends_semanal(topic, pais, fecha_inicio, fecha_fin)
        return trends_data.to_dict()
    except ValueError as ve:
        return {"error": str(ve)}

# Ejemplo de uso
palabra_clave = "Unemployment benefits"
datos = obtener_datos_google_trends_semanal(palabra_clave)
datos
# Out:
#             Unemployment benefits  isPartial
# date
# 2014-01-05                    0.0        0.0
# 2014-01-12                    NaN        NaN
# 2014-01-19                    NaN        NaN
# 2014-01-26                    NaN        NaN
# 2014-02-02                    0.0        0.0
# ...                           ...        ...
# 2024-02-04                    0.0        0.0
# 2024-02-11                    NaN        NaN
# 2024-02-18                    NaN        NaN
# 2024-02-25                    NaN        NaN
# 2024-03-03                    0.0        0.0
#
# [531 rows x 2 columns]

# %%
import time
from pytrends.request import TrendReq
from fastapi import FastAPI
import pandas as pd

app = FastAPI()


def obtener_datos_google_trends_semanal(palabra_clave, pais='GB', fecha_inicio='2014-01-01', fecha_fin='2024-03-31'):
    try:
        pytrends = TrendReq(hl='es', tz=360)
        pytrends.build_payload(kw_list=[palabra_clave], timeframe=f'{fecha_inicio} {fecha_fin}', geo=pais)
        data = pytrends.interest_over_time()
        if data.empty:
            raise ValueError("No hay datos disponibles para la palabra clave y país proporcionados.")
        data_semanal = data.resample('W').mean()
        return data_semanal
    except Exception as e:
        print(f"Error al obtener datos de Google Trends: {e}")
        time.sleep(60)
        return obtener_datos_google_trends_semanal(palabra_clave, pais, fecha_inicio, fecha_fin)

@app.get("/google-trends/{topic}")
def google_trends_handler(topic: str, pais: str = 'GB', fecha_inicio: str = '2014-01-01', fecha_fin: str = '2024-03-31'):
    try:
        trends_data = obtener_datos_google_trends_semanal(topic, pais, fecha_inicio, fecha_fin)
        return trends_data.to_dict()
    except ValueError as ve:
        return {"error": str(ve)}

# Ejemplo de uso
palabra_clave = "Unemployment benefits"
datos = obtener_datos_google_trends_semanal(palabra_clave)
datos
# Out:
#             Unemployment benefits  isPartial
# date
# 2014-01-05                   51.0        0.0
# 2014-01-12                    NaN        NaN
# 2014-01-19                    NaN        NaN
# 2014-01-26                    NaN        NaN
# 2014-02-02                   51.0        0.0
# ...                           ...        ...
# 2024-02-04                   30.0        0.0
# 2024-02-11                    NaN        NaN
# 2024-02-18                    NaN        NaN
# 2024-02-25                    NaN        NaN
# 2024-03-03                   36.0        0.0
#
# [531 rows x 2 columns]

# %% [markdown]
# # la queremos en weekly

# %% [markdown]
#  Labour Market: topic - Unemployment benefits, topic - jobs, topic - Unemployment,
# Welfare &amp; unemployment
#  Credit, Loans &amp; Personal Finance: topic - Investment, topic - Mortgage, topic - Interest
# rate, Credit &amp; lending, Investing
#  Jobs &amp; Education: Education, Jobs
#  Business &amp; Industrial Activity: Construction, consulting &amp; contracting, Business
# services, Transportation &amp; logistics, manufacturing
#  Health: que puede refinarse utilizando la categoría, Medical Facilities &amp; Services

# %%
from pytrends.request import TrendReq
from fastapi import FastAPI
import pandas as pd
import time

app = FastAPI()

country_list = ['AT', 'BE', 'CH', 'CY', 'CZ', 'DE', 'DK', 'EE', 'GR', 'ES',
       'FI', 'FR', 'HU', 'IE', 'IS', 'IT', 'LU', 'ME',
       'MT', 'NL', 'NO', 'PL', 'PT', 'SE', 'SI','UK','GB',
        'LT', 'LV']

def obtener_datos_google_trends_semanal(palabra_clave, paises=country_list, fecha_inicio='2014-01-01', fecha_fin='2024-03-31'):
    try:
        pytrends = TrendReq(hl='es', tz=360)
        trends_data = {}
        for pais in paises:
            try:
                pytrends.build_payload(kw_list=[palabra_clave], timeframe=f'{fecha_inicio} {fecha_fin}', geo=pais)
                data = pytrends.interest_over_time()
                if data.empty:
                    raise ValueError(f"No hay datos disponibles para la palabra clave y país '{pais}'.")
                data_semanal = data.resample('W').mean()
                trends_data[pais] = data_semanal.to_dict()
            except Exception as e:
                print(f"Error al obtener datos de Google Trends para el país '{pais}': {e}")
                # Break off the loop if an error occurs for a country
                break
        return trends_data
    except Exception as e:
        print(f"Error al obtener datos de Google Trends: {e}")
        time.sleep(60)
        return obtener_datos_google_trends_semanal(palabra_clave, paises, fecha_inicio, fecha_fin)

@app.get("/google-trends/{topic}")
def google_trends_handler(topic: str, fecha_inicio: str = '2014-01-01', fecha_fin: str = '2024-03-31'):
    trends_data = obtener_datos_google_trends_semanal(topic, country_list, fecha_inicio, fecha_fin)
    return trends_data


palabra_clave = "Unemployment benefits"
datos = obtener_datos_google_trends_semanal(palabra_clave)
datos

# %%
import pandas as pd

""" ENG: Timestamp('2014-01-05 00:00:00', freq='W-SUN'): This is a timestamp object representing the start of the week on January 5, 2014. The frequency is set to 'W-SUN',
 indicating that the week starts on Sunday.
0.0: This is the interest score for the corresponding week. In this case, it's 0.0, indicating no interest in the specified topic during that week.

ES:Timestamp('2014-01-05 00:00:00', freq='W-SUN'): Este es un objeto de marca de tiempo que representa el inicio de la semana el 5 de enero de 2014. La frecuencia está establecida en 'W-SUN', lo que indica que la semana comienza el domingo.

0.0: Este es el puntaje de interés para la semana correspondiente. En este caso, es 0.0, lo que indica que no hay interés en el tema especificado durante esa semana."""

# Convert 'datos' dictionary to a DataFrame
df = pd.DataFrame.from_dict(datos)

# Convert the DataFrame to a CSV file
df.to_csv('datos.csv', index=True)
df
# Out:
#                                                                       AT
# Unemployment benefits  {2014-01-05 00:00:00: 0.0, 2014-01-12 00:00:00...
# isPartial              {2014-01-05 00:00:00: 0.0, 2014-01-12 00:00:00...

# %%
"""['AT', 'BE', 'CH', 'CY', 'CZ', 'DE', 'DK', 'EE', 'GR', 'ES',
       'FI', 'FR', 'HU', 'IE', 'IS', 'IT', 'LU', 'ME',
      'MT', 'NL', 'NO', 'PL', 'PT', 'SE', 'SI',
 # aqui ya tenemos el stop por el tema de uk 'UK','GB','LT', 'LV']
"""
df.columns.tolist()
# Out:
# ['AT']

# %% [markdown]
# # LETS START

# %% [markdown]
# *Labour Market: topic - Unemployment benefits, topic - jobs, topic - Unemployment,
# Welfare &amp; unemployment

# %%
#Unemployment benefits
from pytrends.request import TrendReq
from fastapi import FastAPI
import pandas as pd
import time

app = FastAPI()

country_list = ['AT', 'BE', 'CH', 'CY', 'CZ', 'DE', 'DK', 'EE', 'GR', 'ES',
       'FI', 'FR', 'HU', 'IE', 'IS', 'IT', 'LU', 'ME',
       'MT', 'NL', 'NO', 'PL', 'PT', 'SE', 'SI','GB',
        'LT', 'LV']

def obtener_datos_google_trends_semanal2(palabra_clave, paises=country_list, fecha_inicio='2014-01-01', fecha_fin='2024-03-31'):
    try:
        pytrends = TrendReq(hl='es', tz=360)
        trends_data = {}
        for pais in paises:
            try:
                pytrends.build_payload(kw_list=[palabra_clave], timeframe=f'{fecha_inicio} {fecha_fin}', geo=pais)
                data = pytrends.interest_over_time()
                if data.empty:
                    raise ValueError(f"No hay datos disponibles para la palabra clave y país '{pais}'.")
                data_semanal = data.resample('W').mean()
                trends_data[pais] = data_semanal.to_dict()
            except Exception as e:
                print(f"Error al obtener datos de Google Trends para el país '{pais}': {e}")
                # Break off the loop if an error occurs for a country
                break
        return trends_data
    except Exception as e:
        print(f"Error al obtener datos de Google Trends: {e}")
        time.sleep(60)
        return obtener_datos_google_trends_semanal2(palabra_clave, paises, fecha_inicio, fecha_fin)

@app.get("/google-trends/{topic}")
def google_trends_handler(topic: str, fecha_inicio: str = '2014-01-01', fecha_fin: str = '2024-03-31'):
    trends_data = obtener_datos_google_trends_semanal(topic, country_list, fecha_inicio, fecha_fin)
    return trends_data


palabra_clave = "Unemployment benefits"
datos2 = obtener_datos_google_trends_semanal2(palabra_clave)
datos2
# Out:
# Error al obtener datos de Google Trends para el país 'BE': The request failed: Google returned a response with code 429
# {'AT': {'Unemployment benefits': {Timestamp('2014-01-05 00:00:00', freq='W-SUN'): 0.0,
#    Timestamp('2014-01-12 00:00:00', freq='W-SUN'): nan,
#    Timestamp('2014-01-19 00:00:00', freq='W-SUN'): nan,
#    Timestamp('2014-01-26 00:00:00', freq='W-SUN'): nan,
#    Timestamp('2014-02-02 00:00:00', freq='W-SUN'): 0.0,
#    Timestamp('2014-02-09 00:00:00', freq='W-SUN'): nan,
#    Timestamp('2014-02-16 00:00:00', freq='W-SUN'): nan,
#    Timestamp('2014-02-23 00:00:00', freq='W-SUN'): nan,
#    Timestamp('2014-03-02 00:00:00', freq='W-SUN'): 0.0,
#    Timestamp('2014-03-09 00:00:00', freq='W-SUN'): nan,
#    Timestamp('2014-03-16 00:00:00', freq='W-SUN'): nan,
#    Timestamp('2014-03-23 00:00:00', freq='W-SUN'): nan,
#    Timestamp('2014-03-30 00:00:00', freq='W-SUN'): nan,
#    Timestamp('2014-04-06 00:00:00', freq='W-SUN'): 0.0,
# ...

# %%
df2 = pd.DataFrame.from_dict(datos2)

# Convert the DataFrame to a CSV file
df2.to_csv('datos2.csv', index=True)
df2
# Out:
#                                                                       AT
# Unemployment benefits  {2014-01-05 00:00:00: 0.0, 2014-01-12 00:00:00...
# isPartial              {2014-01-05 00:00:00: 0.0, 2014-01-12 00:00:00...

# %%
# 28 countries
df2.columns.tolist()
# Out:
# ['AT']

# %%
df2
# Out:
#                                                                       AT
# Unemployment benefits  {2014-01-05 00:00:00: 0.0, 2014-01-12 00:00:00...
# isPartial              {2014-01-05 00:00:00: 0.0, 2014-01-12 00:00:00...

# %% [markdown]
#  Labour Market: topic - Unemployment benefits, topic - jobs, topic - Unemployment,
# Welfare &amp; unemployment
#  Credit, Loans &amp; Personal Finance: topic - Investment, topic - Mortgage, topic - Interest
# rate, Credit &amp; lending, Investing
#  Jobs &amp; Education: Education, Jobs
#  Business &amp; Industrial Activity: Construction, consulting &amp; contracting, Business
# services, Transportation &amp; logistics, manufacturing
#  Health: que puede refinarse utilizando la categoría, Medical Facilities &amp; Services

# %%
#JOBS
from pytrends.request import TrendReq
from fastapi import FastAPI
import pandas as pd
import time

app = FastAPI()

country_list = ['AT', 'BE', 'CH', 'CY', 'CZ', 'DE', 'DK', 'EE', 'GR', 'ES',
       'FI', 'FR', 'HU', 'IE', 'IS', 'IT', 'LU', 'ME',
       'MT', 'NL', 'NO', 'PL', 'PT', 'SE', 'SI','GB',
        'LT', 'LV']

def obtener_datos_google_trends_semanal2(palabra_clave, paises=country_list, fecha_inicio='2014-01-01', fecha_fin='2024-03-31'):
    try:
        pytrends = TrendReq(hl='es', tz=360)
        trends_data = {}
        for pais in paises:
            try:
                pytrends.build_payload(kw_list=[palabra_clave], timeframe=f'{fecha_inicio} {fecha_fin}', geo=pais)
                data = pytrends.interest_over_time()
                if data.empty:
                    raise ValueError(f"No hay datos disponibles para la palabra clave y país '{pais}'.")
                data_semanal = data.resample('W').mean()
                trends_data[pais] = data_semanal.to_dict()
            except Exception as e:
                print(f"Error al obtener datos de Google Trends para el país '{pais}': {e}")
                # Break off the loop if an error occurs for a country
                break
        return trends_data
    except Exception as e:
        print(f"Error al obtener datos de Google Trends: {e}")
        time.sleep(60)
        return obtener_datos_google_trends_semanal2(palabra_clave, paises, fecha_inicio, fecha_fin)

@app.get("/google-trends/{topic}")
def google_trends_handler(topic: str, fecha_inicio: str = '2014-01-01', fecha_fin: str = '2024-03-31'):
    trends_data = obtener_datos_google_trends_semanal(topic, country_list, fecha_inicio, fecha_fin)
    return trends_data


palabra_clave = "Jobs"
datos3 = obtener_datos_google_trends_semanal2(palabra_clave)
datos3

# %%
df3 = pd.DataFrame.from_dict(datos3)

# Convert the DataFrame to a CSV file
df3.to_csv('datos3.csv', index=True)
df3
# Out:
#                                                           AT  \
# Jobs       {2014-01-05 00:00:00: 78.0, 2014-01-12 00:00:0...
# isPartial  {2014-01-05 00:00:00: 0.0, 2014-01-12 00:00:00...
#
#                                                           BE
# Jobs       {2014-01-05 00:00:00: 79.0, 2014-01-12 00:00:0...
# isPartial  {2014-01-05 00:00:00: 0.0, 2014-01-12 00:00:00...

# %%
df3.columns.tolist()
# Out:
# ['AT', 'BE']

# %% [markdown]
# #

# %%
#Welfare &amp; unemployment
from pytrends.request import TrendReq
from fastapi import FastAPI
import pandas as pd
import time

app = FastAPI()

country_list = ['AT', 'BE', 'CH', 'CY', 'CZ', 'DE', 'DK', 'EE', 'GR', 'ES',
       'FI', 'FR', 'HU', 'IE', 'IS', 'IT', 'LU', 'ME',
       'MT', 'NL', 'NO', 'PL', 'PT', 'SE', 'SI','GB',
        'LT', 'LV']

def obtener_datos_google_trends_semanal2(palabra_clave, paises=country_list, fecha_inicio='2014-01-01', fecha_fin='2024-03-31'):
    try:
        pytrends = TrendReq(hl='es', tz=360)
        trends_data = {}
        for pais in paises:
            try:
                pytrends.build_payload(kw_list=[palabra_clave], timeframe=f'{fecha_inicio} {fecha_fin}', geo=pais)
                data = pytrends.interest_over_time()
                if data.empty:
                    raise ValueError(f"No hay datos disponibles para la palabra clave y país '{pais}'.")
                data_semanal = data.resample('W').mean()
                trends_data[pais] = data_semanal.to_dict()
            except Exception as e:
                print(f"Error al obtener datos de Google Trends para el país '{pais}': {e}")
                # Break off the loop if an error occurs for a country
                break
        return trends_data
    except Exception as e:
        print(f"Error al obtener datos de Google Trends: {e}")
        time.sleep(60)
        return obtener_datos_google_trends_semanal2(palabra_clave, paises, fecha_inicio, fecha_fin)

@app.get("/google-trends/{topic}")
def google_trends_handler(topic: str, fecha_inicio: str = '2014-01-01', fecha_fin: str = '2024-03-31'):
    trends_data = obtener_datos_google_trends_semanal(topic, country_list, fecha_inicio, fecha_fin)
    return trends_data


palabra_clave = "Welfare &amp; unemployment"
datos4 = obtener_datos_google_trends_semanal2(palabra_clave)
datos4
# Out:
# Error al obtener datos de Google Trends para el país 'AT': The request failed: Google returned a response with code 429
# {}

# %%
df4 = pd.DataFrame.from_dict(datos4)

# Convert the DataFrame to a CSV file
df4.to_csv('datos4.csv', index=True)
df4
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df4.columns.tolist()
# Out:
# []

# %%
#unemploymets

from pytrends.request import TrendReq
from fastapi import FastAPI
import pandas as pd
import time


app = FastAPI()

country_list = ['AT', 'BE', 'CH', 'CY', 'CZ', 'DE', 'DK', 'EE', 'GR', 'ES',
       'FI', 'FR', 'HU', 'IE', 'IS', 'IT', 'LU', 'ME',
       'MT', 'NL', 'NO', 'PL', 'PT', 'SE', 'SI','GB',
        'LT', 'LV']

def obtener_datos_google_trends_semanal2(palabra_clave, paises=country_list, fecha_inicio='2014-01-01', fecha_fin='2024-03-31'):
    try:
        pytrends = TrendReq(hl='es', tz=360)
        trends_data = {}
        for pais in paises:
            try:
                pytrends.build_payload(kw_list=[palabra_clave], timeframe=f'{fecha_inicio} {fecha_fin}', geo=pais)
                data = pytrends.interest_over_time()
                if data.empty:
                    raise ValueError(f"No hay datos disponibles para la palabra clave y país '{pais}'.")
                data_semanal = data.resample('W').mean()
                trends_data[pais] = data_semanal.to_dict()
            except Exception as e:
                print(f"Error al obtener datos de Google Trends para el país '{pais}': {e}")
                # Break off the loop if an error occurs for a country
                break
        return trends_data
    except Exception as e:
        print(f"Error al obtener datos de Google Trends: {e}")
        time.sleep(60)
        return obtener_datos_google_trends_semanal2(palabra_clave, paises, fecha_inicio, fecha_fin)

@app.get("/google-trends/{topic}")
def google_trends_handler(topic: str, fecha_inicio: str = '2014-01-01', fecha_fin: str = '2024-03-31'):
    trends_data = obtener_datos_google_trends_semanal(topic, country_list, fecha_inicio, fecha_fin)
    return trends_data


palabra_clave = "Unemployment"
datos5 = obtener_datos_google_trends_semanal2(palabra_clave)
datos5
# Out:
# Error al obtener datos de Google Trends para el país 'AT': The request failed: Google returned a response with code 429
# {}

# %%
df5 = pd.DataFrame.from_dict(datos5)

# Convert the DataFrame to a CSV file
df3.to_csv('datos5.csv', index=True)
df5
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# #Credit, Loans &amp; Personal Finance: topic - Investment, topic - Mortgage, topic - Interest rate, Credit &amp; lending, Investing

# %%
from pytrends.request import TrendReq
from fastapi import FastAPI
import pandas as pd
import time

app = FastAPI()

country_list = ['AT', 'BE', 'CH', 'CY', 'CZ', 'DE', 'DK', 'EE', 'GR', 'ES',
       'FI', 'FR', 'HU', 'IE', 'IS', 'IT', 'LU', 'ME',
       'MT', 'NL', 'NO', 'PL', 'PT', 'SE', 'SI','GB',
        'LT', 'LV']

def obtener_datos_google_trends_semanal2(palabra_clave, paises=country_list, fecha_inicio='2014-01-01', fecha_fin='2024-03-31'):
    try:
        pytrends = TrendReq(hl='es', tz=360)
        trends_data = {}
        for pais in paises:
            try:
                pytrends.build_payload(kw_list=[palabra_clave], timeframe=f'{fecha_inicio} {fecha_fin}', geo=pais)
                data = pytrends.interest_over_time()
                if data.empty:
                    raise ValueError(f"No hay datos disponibles para la palabra clave y país '{pais}'.")
                data_semanal = data.resample('W').mean()
                trends_data[pais] = data_semanal.to_dict()
            except Exception as e:
                print(f"Error al obtener datos de Google Trends para el país '{pais}': {e}")
                # Break off the loop if an error occurs for a country
                break
        return trends_data
    except Exception as e:
        print(f"Error al obtener datos de Google Trends: {e}")
        time.sleep(60)
        return obtener_datos_google_trends_semanal2(palabra_clave, paises, fecha_inicio, fecha_fin)

@app.get("/google-trends/{topic}")
def google_trends_handler(topic: str, fecha_inicio: str = '2014-01-01', fecha_fin: str = '2024-03-31'):
    trends_data = obtener_datos_google_trends_semanal(topic, country_list, fecha_inicio, fecha_fin)
    return trends_data


palabra_clave = "Investment"
datos6 = obtener_datos_google_trends_semanal2(palabra_clave)
datos6
# Out:
# Error al obtener datos de Google Trends para el país 'AT': The request failed: Google returned a response with code 429
# {}

# %%
df6 = pd.DataFrame.from_dict(datos6)

# Convert the DataFrame to a CSV file
df6.to_csv('datos6.csv', index=True)
df6
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
from pytrends.request import TrendReq
from fastapi import FastAPI
import pandas as pd
import time

app = FastAPI()

country_list = ['AT', 'BE', 'CH', 'CY', 'CZ', 'DE', 'DK', 'EE', 'GR', 'ES',
       'FI', 'FR', 'HU', 'IE', 'IS', 'IT', 'LU', 'ME',
       'MT', 'NL', 'NO', 'PL', 'PT', 'SE', 'SI','GB',
        'LT', 'LV']

def obtener_datos_google_trends_semanal2(palabra_clave, paises=country_list, fecha_inicio='2014-01-01', fecha_fin='2024-03-31'):
    try:
        pytrends = TrendReq(hl='es', tz=360)
        trends_data = {}
        for pais in paises:
            try:
                pytrends.build_payload(kw_list=[palabra_clave], timeframe=f'{fecha_inicio} {fecha_fin}', geo=pais)
                data = pytrends.interest_over_time()
                if data.empty:
                    raise ValueError(f"No hay datos disponibles para la palabra clave y país '{pais}'.")
                data_semanal = data.resample('W').mean()
                trends_data[pais] = data_semanal.to_dict()
            except Exception as e:
                print(f"Error al obtener datos de Google Trends para el país '{pais}': {e}")
                # Break off the loop if an error occurs for a country
                break
        return trends_data
    except Exception as e:
        print(f"Error al obtener datos de Google Trends: {e}")
        time.sleep(60)
        return obtener_datos_google_trends_semanal2(palabra_clave, paises, fecha_inicio, fecha_fin)

@app.get("/google-trends/{topic}")
def google_trends_handler(topic: str, fecha_inicio: str = '2014-01-01', fecha_fin: str = '2024-03-31'):
    trends_data = obtener_datos_google_trends_semanal(topic, country_list, fecha_inicio, fecha_fin)
    return trends_data


palabra_clave = "Mortgage"
datos7= obtener_datos_google_trends_semanal2(palabra_clave)
datos7
#Error al obtener datos de Google Trends para el país 'LT': The request failed: Google returned a response with code 429
# Out:
# Error al obtener datos de Google Trends para el país 'AT': The request failed: Google returned a response with code 429
# {}

# %%
df7 = pd.DataFrame.from_dict(datos7)

# Convert the DataFrame to a CSV file
df7.to_csv('datos7.csv', index=True)
df7
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df7.columns.tolist()
# Out:
# []

# %%
#checking on LT

import time
from pytrends.request import TrendReq
from fastapi import FastAPI
import pandas as pd

app = FastAPI()

def obtener_datos_google_trends_semanal(palabra_clave, pais='LT', fecha_inicio='2014-01-01', fecha_fin='2024-03-31'):
    try:
        pytrends = TrendReq(hl='es', tz=360)
        pytrends.build_payload(kw_list=[palabra_clave], timeframe=f'{fecha_inicio} {fecha_fin}', geo=pais)
        data = pytrends.interest_over_time()
        if data.empty:
            raise ValueError("No hay datos disponibles para la palabra clave y país proporcionados.")
        data_semanal = data.resample('W').mean()
        return data_semanal
    except Exception as e:
        print(f"Error al obtener datos de Google Trends: {e}")
        time.sleep(60)
        return obtener_datos_google_trends_semanal(palabra_clave, pais, fecha_inicio, fecha_fin)

@app.get("/google-trends/{topic}")
def google_trends_handler(topic: str, pais: str = 'LT', fecha_inicio: str = '2014-01-01', fecha_fin: str = '2024-03-31'):
    try:
        trends_data = obtener_datos_google_trends_semanal(topic, pais, fecha_inicio, fecha_fin)
        return trends_data.to_dict()
    except ValueError as ve:
        return {"error": str(ve)}

# Ejemplo de uso
palabra_clave = "Mortage"
datos = obtener_datos_google_trends_semanal(palabra_clave)
datos
# Out:
#             Mortage  isPartial
# date
# 2014-01-05      0.0        0.0
# 2014-01-12      NaN        NaN
# 2014-01-19      NaN        NaN
# 2014-01-26      NaN        NaN
# 2014-02-02      0.0        0.0
# ...             ...        ...
# 2024-02-04      0.0        0.0
# 2024-02-11      NaN        NaN
# 2024-02-18      NaN        NaN
# 2024-02-25      NaN        NaN
# 2024-03-03      4.0        0.0
#
# [531 rows x 2 columns]

# %%
from pytrends.request import TrendReq
from fastapi import FastAPI
import pandas as pd
import time

app = FastAPI()

country_list = ['AT', 'BE', 'CH', 'DK', 'EE', 'GR', 'ES',
       'FI', 'FR', 'HU', 'IE', 'IS', 'IT', 'LU', 'ME',
       'MT', 'NL', 'NO', 'PL','SE', 'SI',
         'LV']

def obtener_datos_google_trends_semanal2(palabra_clave, paises=country_list, fecha_inicio='2014-01-01', fecha_fin='2024-03-31'):
    try:
        pytrends = TrendReq(hl='es', tz=360)
        trends_data = {}
        for pais in paises:
            try:
                pytrends.build_payload(kw_list=[palabra_clave], timeframe=f'{fecha_inicio} {fecha_fin}', geo=pais)
                data = pytrends.interest_over_time()
                if data.empty:
                    raise ValueError(f"No hay datos disponibles para la palabra clave y país '{pais}'.")
                data_semanal = data.resample('W').mean()
                trends_data[pais] = data_semanal.to_dict()
            except Exception as e:
                print(f"Error al obtener datos de Google Trends para el país '{pais}': {e}")
                # Break off the loop if an error occurs for a country
                break
        return trends_data
    except Exception as e:
        print(f"Error al obtener datos de Google Trends: {e}")
        time.sleep(60)
        return obtener_datos_google_trends_semanal2(palabra_clave, paises, fecha_inicio, fecha_fin)

@app.get("/google-trends/{topic}")
def google_trends_handler(topic: str, fecha_inicio: str = '2014-01-01', fecha_fin: str = '2024-03-31'):
    trends_data = obtener_datos_google_trends_semanal(topic, country_list, fecha_inicio, fecha_fin)
    return trends_data


palabra_clave = "Interest rate, Credit & lending, Investing"
datos8 = obtener_datos_google_trends_semanal2(palabra_clave)
datos8
#Error al obtener datos de Google Trends para el país 'CY': No hay datos disponibles para la palabra clave y país 'CY'.
#Error al obtener datos de Google Trends para el país 'MT': No hay datos disponibles para la palabra clave y país 'MT'.
# Out:
# Error al obtener datos de Google Trends para el país 'AT': The request failed: Google returned a response with code 429
# {}

# %%
df8 = pd.DataFrame.from_dict(datos8)

# Convert the DataFrame to a CSV file
df8.to_csv('datos8.csv', index=True)
df8
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df8.columns.tolist()
#22
# Out:
# []

# %%
# CY checking
import time
from pytrends.request import TrendReq
from fastapi import FastAPI
import pandas as pd

app = FastAPI()

def obtener_datos_google_trends_semanal(palabra_clave, pais='CY', fecha_inicio='2014-01-01', fecha_fin='2024-03-31'):
    try:
        pytrends = TrendReq(hl='es', tz=360)
        pytrends.build_payload(kw_list=[palabra_clave], timeframe=f'{fecha_inicio} {fecha_fin}', geo=pais)
        data = pytrends.interest_over_time()
        if data.empty:
            raise ValueError("No hay datos disponibles para la palabra clave y país proporcionados.")
        data_semanal = data.resample('W').mean()
        return data_semanal
    except Exception as e:
        print(f"Error al obtener datos de Google Trends: {e}")
        time.sleep(60)
        return obtener_datos_google_trends_semanal(palabra_clave, pais, fecha_inicio, fecha_fin)

@app.get("/google-trends/{topic}")
def google_trends_handler(topic: str, pais: str = 'CY', fecha_inicio: str = '2014-01-01', fecha_fin: str = '2024-03-31'):
    try:
        trends_data = obtener_datos_google_trends_semanal(topic, pais, fecha_inicio, fecha_fin)
        return trends_data.to_dict()
    except ValueError as ve:
        return {"error": str(ve)}

# Ejemplo de uso
palabra_clave = "Interest rate, Credit & lending, Investing"
datos = obtener_datos_google_trends_semanal(palabra_clave)
datos
# Out:
# Error al obtener datos de Google Trends: The request failed: Google returned a response with code 429
# Error al obtener datos de Google Trends: The request failed: Google returned a response with code 429
# Error al obtener datos de Google Trends: The request failed: Google returned a response with code 429

# %%
#checkingon CZ negative
#checking on DE negative
#checking 'PT' negative
#PO as POLand just a quick check , negative , PL : positive
# LT : negative
#GB ; NEGATIVE , UK : negative
# LV que es latvia : negative, trying with  LG ; negative

import time
from pytrends.request import TrendReq
from fastapi import FastAPI
import pandas as pd

app = FastAPI()

def obtener_datos_google_trends_semanal(palabra_clave, pais='LG', fecha_inicio='2014-01-01', fecha_fin='2024-03-31'):
    try:
        pytrends = TrendReq(hl='es', tz=360)
        pytrends.build_payload(kw_list=[palabra_clave], timeframe=f'{fecha_inicio} {fecha_fin}', geo=pais)
        data = pytrends.interest_over_time()
        if data.empty:
            raise ValueError("No hay datos disponibles para la palabra clave y país proporcionados.")
        data_semanal = data.resample('W').mean()
        return data_semanal
    except Exception as e:
        print(f"Error al obtener datos de Google Trends: {e}")
        time.sleep(60)
        return obtener_datos_google_trends_semanal(palabra_clave, pais, fecha_inicio, fecha_fin)

@app.get("/google-trends/{topic}")
def google_trends_handler(topic: str, pais: str = 'LG', fecha_inicio: str = '2014-01-01', fecha_fin: str = '2024-03-31'):
    try:
        trends_data = obtener_datos_google_trends_semanal(topic, pais, fecha_inicio, fecha_fin)
        return trends_data.to_dict()
    except ValueError as ve:
        return {"error": str(ve)}

# Ejemplo de uso
palabra_clave = "Interest rate, Credit & lending, Investing"
datos = obtener_datos_google_trends_semanal(palabra_clave)
datos
# Out:
# Error al obtener datos de Google Trends: The request failed: Google returned a response with code 400
# Error al obtener datos de Google Trends: The request failed: Google returned a response with code 400
# Error al obtener datos de Google Trends: The request failed: Google returned a response with code 400
# Error al obtener datos de Google Trends: The request failed: Google returned a response with code 400
# Error al obtener datos de Google Trends: The request failed: Google returned a response with code 400
# Error al obtener datos de Google Trends: The request failed: Google returned a response with code 400
# Error al obtener datos de Google Trends: The request failed: Google returned a response with code 400
# Error al obtener datos de Google Trends: The request failed: Google returned a response with code 400
# Error al obtener datos de Google Trends: The request failed: Google returned a response with code 400
# ...

# %% [markdown]
# #Education: Education, Jobs

# %%
from pytrends.request import TrendReq
from fastapi import FastAPI
import pandas as pd
import time

app = FastAPI()

country_list = ['AT', 'BE', 'CH', 'CY', 'CZ', 'DE', 'DK', 'EE', 'GR', 'ES',
       'FI', 'FR', 'HU', 'IE', 'IS', 'IT', 'LU', 'ME',
       'MT', 'NL', 'NO', 'PL', 'PT', 'SE', 'SI','GB',
        'LT', 'LV']

def obtener_datos_google_trends_semanal2(palabra_clave, paises=country_list, fecha_inicio='2014-01-01', fecha_fin='2024-03-31'):
    try:
        pytrends = TrendReq(hl='es', tz=360)
        trends_data = {}
        for pais in paises:
            try:
                pytrends.build_payload(kw_list=[palabra_clave], timeframe=f'{fecha_inicio} {fecha_fin}', geo=pais)
                data = pytrends.interest_over_time()
                if data.empty:
                    raise ValueError(f"No hay datos disponibles para la palabra clave y país '{pais}'.")
                data_semanal = data.resample('W').mean()
                trends_data[pais] = data_semanal.to_dict()
            except Exception as e:
                print(f"Error al obtener datos de Google Trends para el país '{pais}': {e}")
                # Break off the loop if an error occurs for a country
                break
        return trends_data
    except Exception as e:
        print(f"Error al obtener datos de Google Trends: {e}")
        time.sleep(60)
        return obtener_datos_google_trends_semanal2(palabra_clave, paises, fecha_inicio, fecha_fin)

@app.get("/google-trends/{topic}")
def google_trends_handler(topic: str, fecha_inicio: str = '2014-01-01', fecha_fin: str = '2024-03-31'):
    trends_data = obtener_datos_google_trends_semanal(topic, country_list, fecha_inicio, fecha_fin)
    return trends_data


palabra_clave = "Education"
datos9= obtener_datos_google_trends_semanal2(palabra_clave)
datos9

# %%
df_9 = pd.DataFrame.from_dict(datos9)

# Convert the DataFrame to a CSV file
df_9.to_csv('datos3.csv', index=True)
df_9

# %%
df_9.columns.tolist()

# %%
#checking AT ; POSITIVE
#checking Slovenia SI: Postiive


import time
from pytrends.request import TrendReq
from fastapi import FastAPI
import pandas as pd

app = FastAPI()

def obtener_datos_google_trends_semanal(palabra_clave, pais='SL', fecha_inicio='2014-01-01', fecha_fin='2024-03-31'):
    try:
        pytrends = TrendReq(hl='es', tz=360)
        pytrends.build_payload(kw_list=[palabra_clave], timeframe=f'{fecha_inicio} {fecha_fin}', geo=pais)
        data = pytrends.interest_over_time()
        if data.empty:
            raise ValueError("No hay datos disponibles para la palabra clave y país proporcionados.")
        data_semanal = data.resample('W').mean()
        return data_semanal
    except Exception as e:
        print(f"Error al obtener datos de Google Trends: {e}")
        time.sleep(60)
        return obtener_datos_google_trends_semanal(palabra_clave, pais, fecha_inicio, fecha_fin)

@app.get("/google-trends/{topic}")
def google_trends_handler(topic: str, pais: str = 'SL', fecha_inicio: str = '2014-01-01', fecha_fin: str = '2024-03-31'):
    try:
        trends_data = obtener_datos_google_trends_semanal(topic, pais, fecha_inicio, fecha_fin)
        return trends_data.to_dict()
    except ValueError as ve:
        return {"error": str(ve)}

# Ejemplo de uso
palabra_clave = "Education"
datos = obtener_datos_google_trends_semanal(palabra_clave)
datos

# %%
#checking AT ; POSITIVE
#checking Slovenia SI: Postiive


import time
from pytrends.request import TrendReq
from fastapi import FastAPI
import pandas as pd

app = FastAPI()

def obtener_datos_google_trends_semanal(palabra_clave, pais='SI', fecha_inicio='2014-01-01', fecha_fin='2024-03-31'):
    try:
        pytrends = TrendReq(hl='es', tz=360)
        pytrends.build_payload(kw_list=[palabra_clave], timeframe=f'{fecha_inicio} {fecha_fin}', geo=pais)
        data = pytrends.interest_over_time()
        if data.empty:
            raise ValueError("No hay datos disponibles para la palabra clave y país proporcionados.")
        data_semanal = data.resample('W').mean()
        return data_semanal
    except Exception as e:
        print(f"Error al obtener datos de Google Trends: {e}")
        time.sleep(60)
        return obtener_datos_google_trends_semanal(palabra_clave, pais, fecha_inicio, fecha_fin)

@app.get("/google-trends/{topic}")
def google_trends_handler(topic: str, pais: str = 'SI', fecha_inicio: str = '2014-01-01', fecha_fin: str = '2024-03-31'):
    try:
        trends_data = obtener_datos_google_trends_semanal(topic, pais, fecha_inicio, fecha_fin)
        return trends_data.to_dict()
    except ValueError as ve:
        return {"error": str(ve)}


palabra_clave = "Education"
datos = obtener_datos_google_trends_semanal(palabra_clave)
datos

# %% [markdown]
# # Business &amp; Industrial Activity: Construction, consulting &amp; contracting, Business services, Transportation &amp; logistics, manufacturing

# %%
pytrend = TrendReq()
topics_data = pytrend.suggestions(keyword='Business & Industrial Activity: ')
topics_data

# %%
from pytrends.request import TrendReq
from fastapi import FastAPI
import pandas as pd
import time

app = FastAPI()

country_list = ['AT', 'BE', 'CH', 'CY', 'CZ', 'DE', 'DK', 'EE', 'GR', 'ES',
       'FI', 'FR', 'HU', 'IE', 'IS', 'IT', 'LU', 'ME',
       'MT', 'NL', 'NO', 'PL', 'PT', 'SE', 'SI','GB',
        'LT', 'LV']

def obtener_datos_google_trends_semanal2(palabra_clave, paises=country_list, fecha_inicio='2014-01-01', fecha_fin='2024-03-31'):
    try:
        pytrends = TrendReq(hl='es', tz=360)
        trends_data = {}
        for pais in paises:
            try:
                pytrends.build_payload(kw_list=[palabra_clave], timeframe=f'{fecha_inicio} {fecha_fin}', geo=pais)
                data = pytrends.interest_over_time()
                if data.empty:
                    raise ValueError(f"No hay datos disponibles para la palabra clave y país '{pais}'.")
                data_semanal = data.resample('W').mean()
                trends_data[pais] = data_semanal.to_dict()
            except Exception as e:
                print(f"Error al obtener datos de Google Trends para el país '{pais}': {e}")
                # Break off the loop if an error occurs for a country
                break
        return trends_data
    except Exception as e:
        print(f"Error al obtener datos de Google Trends: {e}")
        time.sleep(60)
        return obtener_datos_google_trends_semanal2(palabra_clave, paises, fecha_inicio, fecha_fin)

@app.get("/google-trends/{topic}")
def google_trends_handler(topic: str, fecha_inicio: str = '2014-01-01', fecha_fin: str = '2024-03-31'):
    trends_data = obtener_datos_google_trends_semanal(topic, country_list, fecha_inicio, fecha_fin)
    return trends_data


palabra_clave = "logistics"
datos9= obtener_datos_google_trends_semanal2(palabra_clave)
datos9

# %% [markdown]
# # Health: que puede refinarse utilizando la categoría, Medical Facilities &amp; Services

# %%
from fastapi import FastAPI
from pytrends.request import TrendReq
import pandas as pd

app = FastAPI()

country_list = ['AT', 'BE', 'CH', 'CY', 'CZ', 'DE', 'DK', 'EE', 'GR', 'ES',
       'FI', 'FR', 'HU', 'IE', 'IS', 'IT', 'LU', 'ME',
       'MT', 'NL', 'NO', 'PL', 'PT', 'SE', 'SI','GB',
        'LT', 'LV']

def obtener_datos_google_trends_semanal2(categoria, paises=country_list, fecha_inicio='2014-01-01', fecha_fin='2024-03-31'):
    try:
        pytrends = TrendReq(hl='es', tz=360)
        trends_data = {}
        for pais in paises:
            try:
                pytrends.build_payload(cat=categoria, timeframe=f'{fecha_inicio} {fecha_fin}', geo=pais)
                data = pytrends.interest_over_time()
                if data.empty:
                    raise ValueError(f"No hay datos disponibles para la categoría y país '{pais}'.")
                data_semanal = data.resample('W').mean()
                trends_data[pais] = data_semanal.to_dict()
            except Exception as e:
                print(f"Error al obtener datos de Google Trends para el país '{pais}': {e}")
                # Break off the loop if an error occurs for a country
                break
        return trends_data
    except Exception as e:
        print(f"Error al obtener datos de Google Trends: {e}")
        # Si hay un error, se espera 60 segundos y se vuelve a intentar
        time.sleep(60)
        return obtener_datos_google_trends_semanal2(categoria, paises, fecha_inicio, fecha_fin)

@app.get("/google-trends/{category}")
def google_trends_handler(category: str, fecha_inicio: str = '2014-01-01', fecha_fin: str = '2024-03-31'):
    # Llama a la función para obtener los datos de Google Trends
    trends_data = obtener_datos_google_trends_semanal2(category, country_list, fecha_inicio, fecha_fin)
    return trends_data


    categoria = "Medical Facilities & Services"
    datos10 = obtener_datos_google_trends_semanal2(categoria)
    print(datos10)
